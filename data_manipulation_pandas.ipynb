# %%
import pandas as pd
import numpy as np

# %%
seri=pd.Series([1,2,3,4])

# %%
seri.axes #datafremim hakkında bilgi verir
# Out:
# [RangeIndex(start=0, stop=4, step=1)]

# %%
seri.size
# Out:
# 4

# %%
seri.ndim #boyut için
# Out:
# 1

# %%
seri.values #indexlere karşılık gelen değerleri getirmek için
# Out:
# array([1, 2, 3, 4])

# %%
seri.head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
seri.tail()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
df=pd.Series([100,23,34,11,26],index=["a","b","c","d","e"])

# %%
df["a":"c"]
# Out:
# a    100
# b     23
# c     34
# dtype: int64

# %%
sozluk={"a":12,"b":23,"c":45}
df=pd.Series(sozluk)

# %%
df
# Out:
# a    12
# b    23
# c    45
# dtype: int64

# %%
m=np.random.randint(1,30,size=(10,3))
df=pd.DataFrame(m,columns=["var1","var2","var3"])
df
# Out:
#    var1  var2  var3
# 0    22    28    11
# 1     7    23    28
# 2     2     1    29
# 3     2    12    19
# 4    14     7     2
# 5     2     3    16
# 6    13    10    25
# 7    14    24    28
# 8     3    20    28
# 9    27    11     4

# %%
df.loc[0:3]
# Out:
#    var1  var2  var3
# 0    22    28    11
# 1     7    23    28
# 2     2     1    29
# 3     2    12    19

# %%
df.iloc[0:3]
# Out:
#    var1  var2  var3
# 0    22    28    11
# 1     7    23    28
# 2     2     1    29

# %%
df.iloc[:2,:2]
# Out:
#    var1  var2
# 0    22    28
# 1     7    23

# %%
df[0:3]
# Out:
#    var1  var2  var3
# 0    22    28    11
# 1     7    23    28
# 2     2     1    29

# %%
df.iloc[0:2,"var2"] #etiket bazlı çalışamazsın
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _validate_tuple_indexer(self, key)
#     965             try:
# --> 966                 self._validate_key(k, i)
#     967             except ValueError as err:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1613         else:
# -> 1614             raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#    1615
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-640809466.py in <cell line: 0>()
# ...

# %%
df.iloc[0:3]["var3"]
# Out:
# 0    11
# 1    28
# 2    29
# Name: var3, dtype: int64

# %%
df.loc[0:2,"var3"]
# Out:
# 0    11
# 1    28
# 2    29
# Name: var3, dtype: int64

# %%
df[df["var1"]>10]
# Out:
#    var1  var2  var3
# 0    22    28    11
# 4    14     7     2
# 6    13    10    25
# 7    14    24    28
# 9    27    11     4

# %%
df[(df["var1"]>10) & (df["var2"]>10)]
# Out:
#    var1  var2  var3
# 0    22    28    11
# 7    14    24    28
# 9    27    11     4

# %%
df[df.var1>5]
# Out:
#    var1  var2  var3
# 0    22    28    11
# 1     7    23    28
# 4    14     7     2
# 6    13    10    25
# 7    14    24    28
# 9    27    11     4

# %%
df[(df.var1>10) & (df.var2<10)]
# Out:
#    var1  var2  var3
# 4    14     7     2

# %%
df.loc[(df.var1>10),["var1","var2"]]
# Out:
#    var1  var2
# 0    22    28
# 4    14     7
# 6    13    10
# 7    14    24
# 9    27    11

# %%
df2=df + 20

# %%
df2
# Out:
#    var1  var2  var3
# 0    42    48    31
# 1    27    43    48
# 2    22    21    49
# 3    22    32    39
# 4    34    27    22
# 5    22    23    36
# 6    33    30    45
# 7    34    44    48
# 8    23    40    48
# 9    47    31    24

# %%
pd.concat([df2,df],ignore_index="True")
# Out:
#     var1  var2  var3
# 0     42    48    31
# 1     27    43    48
# 2     22    21    49
# 3     22    32    39
# 4     34    27    22
# 5     22    23    36
# 6     33    30    45
# 7     34    44    48
# 8     23    40    48
# 9     47    31    24
# 10    22    28    11
# 11     7    23    28
# 12     2     1    29
# 13     2    12    19
# 14    14     7     2
# 15     2     3    16
# 16    13    10    25
# 17    14    24    28
# 18     3    20    28
# 19    27    11     4

# %%
df2.columns=["var1","var2","deg1"]

# %%
df2
# Out:
#    var1  var2  deg1
# 0    42    48    31
# 1    27    43    48
# 2    22    21    49
# 3    22    32    39
# 4    34    27    22
# 5    22    23    36
# 6    33    30    45
# 7    34    44    48
# 8    23    40    48
# 9    47    31    24

# %%
pd.concat([df2,df],ignore_index="True")
# Out:
#     var1  var2  deg1  var3
# 0     42    48  31.0   NaN
# 1     27    43  48.0   NaN
# 2     22    21  49.0   NaN
# 3     22    32  39.0   NaN
# 4     34    27  22.0   NaN
# 5     22    23  36.0   NaN
# 6     33    30  45.0   NaN
# 7     34    44  48.0   NaN
# 8     23    40  48.0   NaN
# 9     47    31  24.0   NaN
# 10    22    28   NaN  11.0
# 11     7    23   NaN  28.0
# 12     2     1   NaN  29.0
# 13     2    12   NaN  19.0
# 14    14     7   NaN   2.0
# 15     2     3   NaN  16.0
# 16    13    10   NaN  25.0
# 17    14    24   NaN  28.0
# 18     3    20   NaN  28.0
# 19    27    11   NaN   4.0

# %%
pd.concat([df2,df],join="inner",ignore_index=True)
# Out:
#     var1  var2
# 0     42    48
# 1     27    43
# 2     22    21
# 3     22    32
# 4     34    27
# 5     22    23
# 6     33    30
# 7     34    44
# 8     23    40
# 9     47    31
# 10    22    28
# 11     7    23
# 12     2     1
# 13     2    12
# 14    14     7
# 15     2     3
# 16    13    10
# 17    14    24
# 18     3    20
# 19    27    11

# %%
df1=pd.DataFrame({
    'Calisanlar':["Ali","Veli","Ayse","Fatma"],
    'Grup':["Muhasebe","Muhendislik","Muhendislik","İk"]
})
df1
# Out:
#   Calisanlar         Grup
# 0        Ali     Muhasebe
# 1       Veli  Muhendislik
# 2       Ayse  Muhendislik
# 3      Fatma           İk

# %%
df2=pd.DataFrame({
    'Calisanlar':["Ayse","Ali","Veli","Fatma"],
    'İl_Giris':[2010,2009,2014,2019]
})
df2
# Out:
#   Calisanlar  İl_Giris
# 0       Ayse      2010
# 1        Ali      2009
# 2       Veli      2014
# 3      Fatma      2019

# %%
#birebir birleştirme
pd.merge(df1,df2)
# Out:
#   Calisanlar         Grup  İl_Giris
# 0        Ali     Muhasebe      2009
# 1       Veli  Muhendislik      2014
# 2       Ayse  Muhendislik      2010
# 3      Fatma           İk      2019

# %%
pd.merge(df1,df2,on="Calisanlar")
# Out:
#   Calisanlar         Grup  İl_Giris
# 0        Ali     Muhasebe      2009
# 1       Veli  Muhendislik      2014
# 2       Ayse  Muhendislik      2010
# 3      Fatma           İk      2019

# %%
#Çoktan teke birleştirme

# %%
df3=pd.merge(df1,df2)

# %%
df3
# Out:
#   Calisanlar         Grup  İl_Giris
# 0        Ali     Muhasebe      2009
# 1       Veli  Muhendislik      2014
# 2       Ayse  Muhendislik      2010
# 3      Fatma           İk      2019

# %%
df4=pd.DataFrame({
    'Grup':["Muhasebe","Muhendislik","Ik"],
    'Mudur':["Caner","Mustafa","Berkcan"]
})
df4
# Out:
#           Grup    Mudur
# 0     Muhasebe    Caner
# 1  Muhendislik  Mustafa
# 2           Ik  Berkcan

# %%
pd.merge(df3,df4)
# Out:
#   Calisanlar         Grup  İl_Giris    Mudur
# 0        Ali     Muhasebe      2009    Caner
# 1       Veli  Muhendislik      2014  Mustafa
# 2       Ayse  Muhendislik      2010  Mustafa

# %%
#Çoktan çoka birleştirme

# %%
df5=pd.DataFrame({
    'Grup':["Muhasebe","Muhasebe","Muhendislik","Muhendislik","IK","IK"],
    'Yetenekler':["matematik","excel","kodlama","linux","excel","yonetim"]
})
df5
# Out:
#           Grup Yetenekler
# 0     Muhasebe  matematik
# 1     Muhasebe      excel
# 2  Muhendislik    kodlama
# 3  Muhendislik      linux
# 4           IK      excel
# 5           IK    yonetim

# %%
df1
# Out:
#   Calisanlar         Grup
# 0        Ali     Muhasebe
# 1       Veli  Muhendislik
# 2       Ayse  Muhendislik
# 3      Fatma           İk

# %%
pd.merge(df1,df5)
# Out:
#   Calisanlar         Grup Yetenekler
# 0        Ali     Muhasebe  matematik
# 1        Ali     Muhasebe      excel
# 2       Veli  Muhendislik    kodlama
# 3       Veli  Muhendislik      linux
# 4       Ayse  Muhendislik    kodlama
# 5       Ayse  Muhendislik      linux

# %%
import seaborn as sns

# Seaborn kütüphanesindeki 'tips' veri setini yükle
df = sns.load_dataset('tips')

# Veri setinin ilk 5 satırını görüntüle
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.keys()
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
list(df.items())
# Out:
# [('total_bill',
#   0      16.99
#   1      10.34
#   2      21.01
#   3      23.68
#   4      24.59
#          ...
#   239    29.03
#   240    27.18
#   241    22.67
#   242    17.82
#   243    18.78
#   Name: total_bill, Length: 244, dtype: float64),
#  ('tip',
#   0      1.01
#   1      1.66
#   2      3.50
#   3      3.31
#   4      3.61
#          ...
#   239    5.92
#   240    2.00
#   241    2.00
#   242    1.75
#   243    3.00
#   Name: tip, Length: 244, dtype: float64),
#  ('sex',
#   0      Female
#   1        Male
#   2        Male
#   3        Male
#   4      Female
#           ...
#   239      Male
#   240    Female
#   241      Male
#   242      Male
#   243    Female
#   Name: sex, Length: 244, dtype: category
#   Categories (2, object): ['Male', 'Female']),
#  ('smoker',
#   0       No
#   1       No
#   2       No
#   3       No
#   4       No
#         ...
#   239     No
#   240    Yes
#   241    Yes
#   242     No
#   243     No
# ...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df["total_bill"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
ekleme={"total_bill":[234],
        "tip":[1.02],
        "sex":["Male"],
        "smoker":["Yes"],
        "day":["Thur"],
        "time":["Dinner"],
        "size":[2]
        }
ekleme_df=pd.DataFrame(ekleme)

# %%
ekleme_df
# Out:
#    total_bill   tip   sex smoker   day    time  size
# 0         234  1.02  Male    Yes  Thur  Dinner     2

# %%
x=pd.concat([df,ekleme_df],ignore_index=True)

# %%
x
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 244      234.00  1.02    Male    Yes  Thur  Dinner     2
#
# [245 rows x 7 columns]

# %%
x.drop(244,axis=0,inplace=True)

# %%
x
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#fancy ile silme
deleted_index=[1,2,3,4]
x.drop(deleted_index,axis=0,inplace=True)

# %%
x =x.reset_index(drop=True)

# %%
x
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         25.29  4.71    Male     No   Sun  Dinner     4
# 2          8.77  2.00    Male     No   Sun  Dinner     2
# 3         26.88  3.12    Male     No   Sun  Dinner     4
# 4         15.04  1.96    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 235       29.03  5.92    Male     No   Sat  Dinner     3
# 236       27.18  2.00  Female    Yes   Sat  Dinner     2
# 237       22.67  2.00    Male    Yes   Sat  Dinner     2
# 238       17.82  1.75    Male     No   Sat  Dinner     2
# 239       18.78  3.00  Female     No  Thur  Dinner     2
#
# [240 rows x 7 columns]

# %%
x["person_calculate"]=x["total_bill"]/x["size"]

# %%
x
# Out:
#      total_bill   tip     sex smoker   day    time  size  person_calculate
# 0         16.99  1.01  Female     No   Sun  Dinner     2          8.495000
# 1         25.29  4.71    Male     No   Sun  Dinner     4          6.322500
# 2          8.77  2.00    Male     No   Sun  Dinner     2          4.385000
# 3         26.88  3.12    Male     No   Sun  Dinner     4          6.720000
# 4         15.04  1.96    Male     No   Sun  Dinner     2          7.520000
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 235       29.03  5.92    Male     No   Sat  Dinner     3          9.676667
# 236       27.18  2.00  Female    Yes   Sat  Dinner     2         13.590000
# 237       22.67  2.00    Male    Yes   Sat  Dinner     2         11.335000
# 238       17.82  1.75    Male     No   Sat  Dinner     2          8.910000
# 239       18.78  3.00  Female     No  Thur  Dinner     2          9.390000
#
# [240 rows x 8 columns]

# %%
df=sns.load_dataset("planets")
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
df.dropna().describe()
# Out:
#           number  orbital_period        mass    distance         year
# count  498.00000      498.000000  498.000000  498.000000   498.000000
# mean     1.73494      835.778671    2.509320   52.068213  2007.377510
# std      1.17572     1469.128259    3.636274   46.596041     4.167284
# min      1.00000        1.328300    0.003600    1.350000  1989.000000
# 25%      1.00000       38.272250    0.212500   24.497500  2005.000000
# 50%      1.00000      357.000000    1.245000   39.940000  2009.000000
# 75%      2.00000      999.600000    2.867500   59.332500  2011.000000
# max      6.00000    17337.500000   25.000000  354.000000  2014.000000

# %%
df.dropna().describe().T #Buradaki T satırları sütun,sütunları satır yapar.
# Out:
#                 count         mean          std        min         25%  \
# number          498.0     1.734940     1.175720     1.0000     1.00000
# orbital_period  498.0   835.778671  1469.128259     1.3283    38.27225
# mass            498.0     2.509320     3.636274     0.0036     0.21250
# distance        498.0    52.068213    46.596041     1.3500    24.49750
# year            498.0  2007.377510     4.167284  1989.0000  2005.00000
#
#                      50%        75%      max
# number             1.000     2.0000      6.0
# orbital_period   357.000   999.6000  17337.5
# mass               1.245     2.8675     25.0
# distance          39.940    59.3325    354.0
# year            2009.000  2011.0000   2014.0

# %%
df.groupby("method").count()
# Out:
#                                number  orbital_period  mass  distance  year
# method
# Astrometry                          2               2     0         2     2
# Eclipse Timing Variations           9               9     2         4     9
# Imaging                            38              12     0        32    38
# Microlensing                       23               7     0        10    23
# Orbital Brightness Modulation       3               3     0         2     3
# Pulsar Timing                       5               5     0         1     5
# Pulsation Timing Variations         1               1     0         0     1
# Radial Velocity                   553             553   510       530   553
# Transit                           397             397     1       224   397
# Transit Timing Variations           4               3     0         3     4

# %%
#aggregeta
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df.groupby("method")["orbital_period"].agg(["min", np.median, "max"])
# Out:
# /tmp/ipython-input-1288734563.py:1: FutureWarning: The provided callable <function median at 0x7f88d473fd80> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.groupby("method")["orbital_period"].agg(["min", np.median, "max"])
#                                        min        median            max
# method
# Astrometry                      246.360000    631.180000    1016.000000
# Eclipse Timing Variations      1916.250000   4343.500000   10220.000000
# Imaging                        4639.150000  27500.000000  730000.000000
# Microlensing                   1825.000000   3300.000000    5100.000000
# Orbital Brightness Modulation     0.240104      0.342887       1.544929
# Pulsar Timing                     0.090706     66.541900   36525.000000
# Pulsation Timing Variations    1170.000000   1170.000000    1170.000000
# ...

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.groupby("method").agg({"number":"count","orbital_period":"max"})
# Out:
#                                number  orbital_period
# method
# Astrometry                          2     1016.000000
# Eclipse Timing Variations           9    10220.000000
# Imaging                            38   730000.000000
# Microlensing                       23     5100.000000
# Orbital Brightness Modulation       3        1.544929
# Pulsar Timing                       5    36525.000000
# Pulsation Timing Variations         1     1170.000000
# Radial Velocity                   553    17337.500000
# Transit                           397      331.600590
# Transit Timing Variations           4      160.000000

# %%
#filter

# %%
def filter_func(x):
  return x["orbital_period"].std()>20

# %%
df.groupby("method").filter(filter_func).head(5)
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.apply(np.sum)
# Out:
# method            Radial VelocityRadial VelocityRadial VelocityR...
# number                                                         1848
# orbital_period                                       1986894.255326
# mass                                                     1353.37638
# distance                                                  213367.98
# year                                                        2079388
# dtype: object

# %%
df.groupby("method").apply(np.mean)
# Out:
# method
# Astrometry                         665.388750
# Eclipse Timing Variations         1883.075455
# Imaging                          12479.473000
# Microlensing                      1742.333333
# Orbital Brightness Modulation      763.829811
# Pulsar Timing                     2994.881625
# Pulsation Timing Variations       1059.333333
# Radial Velocity                    591.002188
# Transit                            665.154494
# Transit Timing Variations          829.382179
# dtype: float64

# %%
df.groupby("method").apply(np.mean,axis=0)
# Out:
#                                  number  orbital_period      mass  \
# method
# Astrometry                     1.000000      631.180000       NaN
# Eclipse Timing Variations      1.666667     4751.644444  5.125000
# Imaging                        1.315789   118247.737500       NaN
# Microlensing                   1.173913     3153.571429       NaN
# Orbital Brightness Modulation  1.666667        0.709307       NaN
# Pulsar Timing                  2.200000     7343.021201       NaN
# Pulsation Timing Variations    1.000000     1170.000000       NaN
# Radial Velocity                1.721519      823.354680  2.630699
# Transit                        1.954660       21.102073  1.470000
# Transit Timing Variations      2.250000       79.783500       NaN
#
#                                   distance         year
# method
# Astrometry                       17.875000  2011.500000
# Eclipse Timing Variations       315.360000  2010.000000
# ...

# %%
titanic=sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.groupby("sex")["survived"].mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
titanic.groupby(["sex","class"])["survived"].agg("mean").unstack()
# Out:
# /tmp/ipython-input-233227211.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby(["sex","class"])["survived"].agg("mean").unstack()
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
titanic.groupby(["sex","class"])["survived"].agg("mean")
# Out:
# /tmp/ipython-input-1429347860.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby(["sex","class"])["survived"].agg("mean")
# sex     class
# female  First     0.968085
#         Second    0.921053
#         Third     0.500000
# male    First     0.368852
#         Second    0.157407
#         Third     0.135447
# Name: survived, dtype: float64

# %%
titanic.pivot_table("survived",index="sex",columns="class")#index=satır
# Out:
# /tmp/ipython-input-445771651.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   titanic.pivot_table("survived",index="sex",columns="class")#index=satır
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
age=pd.cut(titanic["age"],[0,18,90])#age sütunun böldü

# %%
age.head(10)
# Out:
# 0    (18.0, 90.0]
# 1    (18.0, 90.0]
# 2    (18.0, 90.0]
# 3    (18.0, 90.0]
# 4    (18.0, 90.0]
# 5             NaN
# 6    (18.0, 90.0]
# 7     (0.0, 18.0]
# 8    (18.0, 90.0]
# 9     (0.0, 18.0]
# Name: age, dtype: category
# Categories (2, interval[int64, right]): [(0, 18] < (18, 90]]

# %%
titanic.pivot_table("survived",index=["sex",age],columns="class")
# Out:
# /tmp/ipython-input-3548605741.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   titanic.pivot_table("survived",index=["sex",age],columns="class")
# class               First    Second     Third
# sex    age
# female (0, 18]   0.909091  1.000000  0.511628
#        (18, 90]  0.972973  0.900000  0.423729
# male   (0, 18]   0.800000  0.600000  0.215686
#        (18, 90]  0.375000  0.071429  0.133663

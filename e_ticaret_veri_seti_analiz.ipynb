# %% [markdown]
# # **Veri Bilimi Eğitimi**
# # Veri Setini Tanıma
#
# Amaç:
#
#
# 1.   Veri setinin genel yapısını tanımak ve temel özelliklerini incelemek
# 2.   Veri analizi öncesi gerekli ilk kontrolleri uygulamak
#
# Adımlar:
#
#
# 1.   Veri setini yükle
# 2.   Veri setinin ilk ve son satırlarını incelemek
# 3.   Veri setinin boyutunu ve sütunlarını kontrol etmek
# 4.   Veri setinin genel bilgisini incele
# 5.   Özel istatistikleri görüntüle
# 6.   Veri tiplerini kontrol et
# 7.   Sayısal ve kategorik sütunları ayırmak
# 8.   Benzersiz(unique) değer sayılarını incelemek

# %%
import pandas as pd

# %%
#1. Veri setini yüklemek
df=pd.read_csv("/content/e_ticaret_veri_seti.csv")

# %%
#2.Veri setinin ilk ve son satırlarını incele
df.head()
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul            Marmara
# 1  SIP100837    MUS1347  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu
# 2  SIP100050    MUS1066  2025-06-03 12:42:00    Kayseri         İç Anadolu
# 3  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 4  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
#
#      kategori              urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik          Nemlendirici     1       414.51           0.05
# 1        Spor           Dambıl Seti     2      1475.15           0.10
# 2       Kitap  İş Analitiği Rehberi     1       289.02           0.05
# 3       Kitap          Girişimcilik     5       194.78           0.00
# 4  Elektronik             Powerbank     3       841.80           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          29.9     Banka Kartı          VIP            4.0            1.0
# 2          29.9     Kredi Kartı       Mevcut            6.0            2.0
# 3          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 4          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar
# 0       Hayır            0.220        443.68
# 1       Hayır            0.361       2685.17
# 2       Hayır            0.348        304.47
# 3       Hayır            0.250       1023.80
# 4       Hayır            0.280       2439.03

# %%
df.tail()
# Out:
#      siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 1423  SIP101093    MUS1187  2024-06-08 20:42:00   İstanbul            Marmara
# 1424  SIP101193    MUS1297  2025-11-06 08:17:00  Gaziantep  Güneydoğu Anadolu
# 1425  SIP101210    MUS1122  2025-03-07 09:07:00        NaN            Marmara
# 1426  SIP101060    MUS1189  2025-04-19 21:52:00    Kocaeli            Marmara
# 1427  SIP100642    MUS1289  2024-09-22 16:36:00     Ankara         İç Anadolu
#
#         kategori         urun_adi  adet  birim_fiyat  indirim_orani  \
# 1423        Spor        Yoga Matı     1       772.23           0.00
# 1424        Spor            Suluk     2       187.03           0.00
# 1425  Elektronik           Webcam     4       894.47           0.10
# 1426       Kitap  Veri Bilimi 101     2       248.55           0.05
# 1427    Kozmetik      Güneş Kremi     1       424.84           0.20
#
#       kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 1423          29.9     Kredi Kartı       Mevcut            3.0            2.0
# 1424          59.9     Kredi Kartı         Yeni            2.0            4.0
# 1425          49.9     Kredi Kartı       Mevcut            3.0            5.0
# 1426          59.9     banka karti         Yeni            4.0            3.0
# 1427           0.0  Dijital Cüzdan         Yeni            2.0            4.0
#
#      iade_durumu  kar_marji_orani  toplam_tutar
# 1423       Hayır            0.275        802.13
# 1424        Evet            0.243        433.96
# 1425       Hayır            0.355       3269.99
# 1426       Hayır            0.373        532.14
# 1427       Hayır            0.317        339.87

# %%
#3.Veri setinin boyutunu ve sütunlarını kontrol etme
satir_sayisi=df.shape[0]
satir_sayisi
# Out:
# 1428

# %%
sutun_sayisi=df.shape[1]
sutun_sayisi
# Out:
# 18

# %%
for i,sutun in enumerate(df.columns,start=1):
  print(f"{i}.{sutun}")
#enumerate:sütun isimlerini numaralandırmak için kullanılır.
# Out:
# 1.siparis_id
# 2.musteri_id
# 3.siparis_tarihi
# 4.sehir
# 5.bolge
# 6.kategori
# 7.urun_adi
# 8.adet
# 9.birim_fiyat
# 10.indirim_orani
# 11.kargo_ucreti
# 12.odeme_turu
# 13.musteri_tipi
# 14.teslimat_gunu
# 15.musteri_puani
# 16.iade_durumu
# 17.kar_marji_orani
# 18.toplam_tutar

# %%
#4.Veri setinin genel bilgisini inceleme
df.info()#sütun isimlerini,veri tiplerini,missing value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428 entries, 0 to 1427
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   siparis_id       1428 non-null   object
#  1   musteri_id       1428 non-null   object
#  2   siparis_tarihi   1428 non-null   object
#  3   sehir            1403 non-null   object
#  4   bolge            1428 non-null   object
#  5   kategori         1428 non-null   object
#  6   urun_adi         1428 non-null   object
#  7   adet             1428 non-null   int64
#  8   birim_fiyat      1428 non-null   float64
#  9   indirim_orani    1412 non-null   float64
#  10  kargo_ucreti     1428 non-null   float64
#  11  odeme_turu       1393 non-null   object
#  12  musteri_tipi     1386 non-null   object
#  13  teslimat_gunu    1400 non-null   float64
#  14  musteri_puani    1372 non-null   float64
#  15  iade_durumu      1428 non-null   object
#  16  kar_marji_orani  1428 non-null   float64
#  17  toplam_tutar     1428 non-null   float64
# dtypes: float64(7), int64(1), object(10)
# memory usage: 200.9+ KB

# %%
#özel istatistikleri görüntüleme
df.describe()#sayısal sütunlar için temel istatistikler
# Out:
#               adet   birim_fiyat  indirim_orani  kargo_ucreti  teslimat_gunu  \
# count  1428.000000   1428.000000    1412.000000   1428.000000    1400.000000
# mean      2.136555    658.477654       0.052054     39.725140       3.370714
# std       2.015770   1042.414639       0.060115     14.185017       1.825990
# min       1.000000     93.110000       0.000000      0.000000       1.000000
# 25%       1.000000    199.185000       0.000000     29.900000       2.000000
# 50%       2.000000    287.120000       0.050000     39.900000       3.000000
# 75%       3.000000    819.177500       0.100000     49.900000       4.000000
# max      38.000000  18145.230000       0.200000     59.900000      31.000000
#
#        musteri_puani  kar_marji_orani  toplam_tutar
# count    1372.000000      1428.000000   1428.000000
# mean        4.002187         0.302799   1370.590336
# std         1.096707         0.069795   2961.689500
# min         0.000000         0.180000     89.680000
# 25%         3.000000         0.244750    323.855000
# 50%         4.000000         0.305000    669.135000
# 75%         5.000000         0.362000   1390.950000
# max         7.000000         0.420000  63870.200000

# %%
#6.Veri tiplerini kontrol etme
df.dtypes
# Out:
# siparis_id          object
# musteri_id          object
# siparis_tarihi      object
# sehir               object
# bolge               object
# kategori            object
# urun_adi            object
# adet                 int64
# birim_fiyat        float64
# indirim_orani      float64
# kargo_ucreti       float64
# odeme_turu          object
# musteri_tipi        object
# teslimat_gunu      float64
# musteri_puani      float64
# iade_durumu         object
# kar_marji_orani    float64
# toplam_tutar       float64
# dtype: object

# %%
#7.Sayısal ve kategorik sütunların ayrılması
sayisal_sutunlar=df.select_dtypes(include=["int64","float64"]).columns
sayisal_sutunlar
# Out:
# Index(['adet', 'birim_fiyat', 'indirim_orani', 'kargo_ucreti', 'teslimat_gunu',
#        'musteri_puani', 'kar_marji_orani', 'toplam_tutar'],
#       dtype='object')

# %%
#8.Benzersiz (unique) değer sayılarını incelemek
for sutun in df.columns:
  print(f"{sutun}:{df[sutun].nunique()}")
# Out:
# siparis_id:1400
# musteri_id:422
# siparis_tarihi:1398
# sehir:19
# bolge:6
# kategori:15
# urun_adi:30
# adet:10
# birim_fiyat:1381
# indirim_orani:5
# kargo_ucreti:5
# odeme_turu:12
# musteri_tipi:7
# teslimat_gunu:11
# musteri_puani:8
# iade_durumu:2
# kar_marji_orani:241
# toplam_tutar:1397

# %% [markdown]
# # Kayıp Veri(Missing Value)
#
# Amaç:
#
#
# 1.   Eksik veri tespiti ve farklı eksik veri çözüm yöntemlerini uygulamak
# 2.   Eğitimde kullanılacak güncel veri setini kaydetme
#
# Adımlar:
#
# 1.   Veri setini yükleme
# 2.   Eksik verileri tespit etme
# 3.   Eksik veri oranlarını hesaplama
# 4.   Eksik veri içeren satırları inceleme
# 5.   Eksik verileri silmek
# 6.   Sayısal eksik verileri ortalama ile doldur
# 7.   Sayısal eksik verileri medyan ile doldur
# 8.   Sayısal eksik verileri mod ile doldur
# 9.   Kategorik eksik verileri mod ile doldur
# 10.  Kategorik eksik verileri sabit bir değer ile doldurmak
# 11.  Eğitimde kullanıcalak olan güncel veri setini oluşturmak
# 12.  Düzenlenmiş veri setini kaydet

# %%
#1.veri setini yükle
#2.eksik verileri tespit etme
df.isnull().sum()
# Out:
# siparis_id          0
# musteri_id          0
# siparis_tarihi      0
# sehir              25
# bolge               0
# kategori            0
# urun_adi            0
# adet                0
# birim_fiyat         0
# indirim_orani      16
# kargo_ucreti        0
# odeme_turu         35
# musteri_tipi       42
# teslimat_gunu      28
# musteri_puani      56
# iade_durumu         0
# kar_marji_orani     0
# toplam_tutar        0
# dtype: int64

# %%
#3.eksik veri oranlarını hesapla
eksik_sayilari=df.isnull().sum()
eksik_oranlari=100*(eksik_sayilari/len(df))
eksik_oranlari
# Out:
# siparis_id         0.000000
# musteri_id         0.000000
# siparis_tarihi     0.000000
# sehir              1.750700
# bolge              0.000000
# kategori           0.000000
# urun_adi           0.000000
# adet               0.000000
# birim_fiyat        0.000000
# indirim_orani      1.120448
# kargo_ucreti       0.000000
# odeme_turu         2.450980
# musteri_tipi       2.941176
# teslimat_gunu      1.960784
# musteri_puani      3.921569
# iade_durumu        0.000000
# kar_marji_orani    0.000000
# toplam_tutar       0.000000
# dtype: float64

# %%
#4.eksik veri içeren satırları incele
eksik_veri_olan_satirlar=df[df.isnull().any(axis=1)]#satırda boş değer var mı
eksik_veri_olan_satirlar.head(10)
# Out:
#    siparis_id musteri_id       siparis_tarihi     sehir       bolge  \
# 19  SIP100677    MUS1148  2024-07-11 16:24:00     Adana     Akdeniz
# 33  SIP101126    MUS1406  2024-09-11 20:05:00    Mersin     Akdeniz
# 50  SIP101040    MUS1386  2025-04-01 09:30:00   Trabzon   Karadeniz
# 60  SIP100890    MUS1271  2024-11-07 19:47:00     İzmir         Ege
# 61  SIP101317    MUS1060  2024-09-05 20:49:00       NaN     Akdeniz
# 70  SIP100715    MUS1033  2024-11-10 21:50:00  İstanbul     Marmara
# 82  SIP100807    MUS1431  2025-01-07 14:12:00    Ankara  İç Anadolu
# 84  SIP100679    MUS1310  2024-05-20 18:51:00     İzmir         Ege
# 86  SIP101071    MUS1131  2024-09-18 12:24:00       NaN  İç Anadolu
# 92  SIP101366    MUS1347  2025-03-04 14:00:00     Bursa     Marmara
#
#        kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 19         Spor         Dambıl Seti     4      1517.65            0.0
# 33   Elektronik  Bluetooth Hoparlör     1      1159.89            0.1
# 50         Spor         Dambıl Seti     1      1554.15            0.0
# 60        Kitap        Girişimcilik     4       216.38            NaN
# 61  Ev ve Yaşam      Saklama Kutusu     1       233.63            0.1
# 70  Ev ve Yaşam              Termos     1       552.05            0.0
# 82     Kozmetik         Güneş Kremi     1       451.28            0.0
# 84  Ev ve Yaşam              Termos     2       477.62            0.0
# 86   Elektronik           Powerbank     1       816.74            0.0
# 92  Ev ve Yaşam           Organizer     1       272.40            0.0
#
#     kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 19          29.9    Kapıda Ödeme       Mevcut            3.0            NaN
# 33          39.9     Kredi Kartı          NaN            2.0            4.0
# 50          49.9     Banka Kartı          NaN            4.0            5.0
# 60          49.9     Kredi Kartı         Yeni            1.0            3.0
# 61          29.9  Dijital Cüzdan         Yeni            5.0            2.0
# 70          39.9             NaN       Mevcut            2.0            3.0
# 82          49.9     Kredi Kartı          NaN            4.0            5.0
# 84          49.9     Kredi Kartı       Mevcut            NaN            4.0
# 86          39.9     Banka Kartı         Yeni            3.0            5.0
# 92          29.9     Kredi Kartı       Mevcut            1.0            NaN
#
#    iade_durumu  kar_marji_orani  toplam_tutar
# 19       Hayır            0.311       6100.50
# 33       Hayır            0.204       1083.80
# 50       Hayır            0.217       1604.05
# 60       Hayır            0.199        915.42
# 61       Hayır            0.385        240.17
# 70       Hayır            0.185        591.95
# 82       Hayır            0.315        501.18
# 84       Hayır            0.323       1005.14
# 86       Hayır            0.301        856.64
# 92       Hayır            0.212        302.30

# %%
#5.Eksik verileri silme
df_silinen=df.dropna()

# %%
df_silinen.shape
# Out:
# (1239, 18)

# %%
#6.sayısal eksik verilerin ortalam ile doldurulması
df_ortalama=df.copy()
sayisal_sutunlar=df_ortalama.select_dtypes(include=["int64","float64"]).columns
sayisal_sutunlar
# Out:
# Index(['adet', 'birim_fiyat', 'indirim_orani', 'kargo_ucreti', 'teslimat_gunu',
#        'musteri_puani', 'kar_marji_orani', 'toplam_tutar'],
#       dtype='object')

# %%
for sutun in sayisal_sutunlar:
  df_ortalama[sutun]=df_ortalama[sutun].fillna(df_ortalama[sutun].mean())

# %%
df_ortalama[sayisal_sutunlar].isnull().sum()
# Out:
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# teslimat_gunu      0
# musteri_puani      0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
#7.sayısal eksik verileri medyan ile doldurma
df_medyan=df.copy()
for sutun in sayisal_sutunlar:
  df_medyan[sutun]=df_medyan[sutun].fillna(df_medyan[sutun].median())
df_medyan[sayisal_sutunlar].isnull().sum()
# Out:
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# teslimat_gunu      0
# musteri_puani      0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
#8.Sayısal eksik verileri mod ile doldurma
df_mod_sayisal=df.copy()
for sutun in sayisal_sutunlar:
  mod_degeri=df_mod_sayisal[sutun].mode()[0]#sadece bir tane değeri al
  df_mod_sayisal[sutun]=df_mod_sayisal[sutun].fillna(mod_degeri)
df_mod_sayisal[sayisal_sutunlar].isnull().sum()
# Out:
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# teslimat_gunu      0
# musteri_puani      0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
#9.Kategorik ekisk verileri mod ile doldurma
df_mod_kategorik=df.copy()
kategorik_sutunlar=df_mod_kategorik.select_dtypes(include=["object"]).columns
kategorik_sutunlar
# Out:
# Index(['siparis_id', 'musteri_id', 'siparis_tarihi', 'sehir', 'bolge',
#        'kategori', 'urun_adi', 'odeme_turu', 'musteri_tipi', 'iade_durumu'],
#       dtype='object')

# %%
for sutun in kategorik_sutunlar:
  mod_degeri=df_mod_kategorik[sutun].mode()[0]
  df_mod_kategorik[sutun]=df_mod_kategorik[sutun].fillna(mod_degeri)

# %%
df_mod_kategorik[kategorik_sutunlar].isnull().sum()
# Out:
# siparis_id        0
# musteri_id        0
# siparis_tarihi    0
# sehir             0
# bolge             0
# kategori          0
# urun_adi          0
# odeme_turu        0
# musteri_tipi      0
# iade_durumu       0
# dtype: int64

# %%
#10.Kategorik eksik verileri sabit bir değer ile doldurmak
df_sabit_kategorik=df.copy()
for sutun in kategorik_sutunlar:
  df_sabit_kategorik[sutun]=df_sabit_kategorik[sutun].fillna("Bilinmiyor")

# %%
df_sabit_kategorik[kategorik_sutunlar].isnull().sum()
# Out:
# siparis_id        0
# musteri_id        0
# siparis_tarihi    0
# sehir             0
# bolge             0
# kategori          0
# urun_adi          0
# odeme_turu        0
# musteri_tipi      0
# iade_durumu       0
# dtype: int64

# %%
#11.Eğitimde kullanacağımız güncel veri seti
#-sayısal eksik verileri medyan ile doldur
#-kategorik eksik verileri mod ile doldur
df_guncel=df.copy()
for sutun in sayisal_sutunlar:
  df_guncel[sutun]=df_guncel[sutun].fillna(df_guncel[sutun].median())

for sutun in kategorik_sutunlar:
  mod_degeri=df_guncel[sutun].mode()[0]
  df_guncel[sutun]=df_guncel[sutun].fillna(mod_degeri)

# %%
df_guncel.isnull().sum()
# Out:
# siparis_id         0
# musteri_id         0
# siparis_tarihi     0
# sehir              0
# bolge              0
# kategori           0
# urun_adi           0
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# odeme_turu         0
# musteri_tipi       0
# teslimat_gunu      0
# musteri_puani      0
# iade_durumu        0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
# 12. düzenlenmiş veri setini kaydedelim
kayit_dosyasi = "e_ticaret_veri_seti_eksik_veriler_duzenlendi.csv"
df_guncel.to_csv(kayit_dosyasi, index = False)

# %% [markdown]
# # ** Veri Tipleri ve Dönüşümler**
#
# Amaç:
#
# 1.   Veri setindeki veri tiplerini incelemek ve gerekli dönüşümleri uygulamak
# 2.   Eğitimde kullanılacak güncel veri setini oluşturarak kaydetmek
#
# Adımlar
#
# 1.   Veri setini yüklemek
# 2.   Veri tiplerini incelemek
# 3.   Sayısal,kategorik ve tarih sütunlarını belirlemek
# 4.   Sipariş tarihi sütununu datetime tipine dönüştürmek(string -> datetime)
# 5.   Tarih sütunundan yeni özellikler üretmek (Feature xtraction)
# 6.   Kategirok sütnları category tipine dönüştürmek(string ->category)
# 7.   Dönüşüm sonrası veri tipi kontrol etmek
# 8.   Güncellenmiş veri setini kaydetmek

# %%
#1.Veri setini yüklemek
#2.Veri tiplerini incelemek
df.dtypes
# Out:
# siparis_id          object
# musteri_id          object
# siparis_tarihi      object
# sehir               object
# bolge               object
# kategori            object
# urun_adi            object
# adet                 int64
# birim_fiyat        float64
# indirim_orani      float64
# kargo_ucreti       float64
# odeme_turu          object
# musteri_tipi        object
# teslimat_gunu      float64
# musteri_puani      float64
# iade_durumu         object
# kar_marji_orani    float64
# toplam_tutar       float64
# dtype: object

# %%
#3.Sayısal,kategorik ve tarih sütunlarını belirlemek
sayisal_sutunlar=df.select_dtypes(include=["int64","float64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar']

# %%
kategorik_sutunlar=df.select_dtypes(include=["object"]).columns.tolist()
kategorik_sutunlar
# Out:
# ['siparis_id',
#  'musteri_id',
#  'siparis_tarihi',
#  'sehir',
#  'bolge',
#  'kategori',
#  'urun_adi',
#  'odeme_turu',
#  'musteri_tipi',
#  'iade_durumu']

# %%
#4.Sipariş tarihi sütununu datetime tipine dönüştürmek (string -> datetime)
df["siparis_tarihi"]=pd.to_datetime(df["siparis_tarihi"])
df["siparis_tarihi"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.dtypes
# Out:
# siparis_id                 object
# musteri_id                 object
# siparis_tarihi     datetime64[ns]
# sehir                      object
# bolge                      object
# kategori                   object
# urun_adi                   object
# adet                        int64
# birim_fiyat               float64
# indirim_orani             float64
# kargo_ucreti              float64
# odeme_turu                 object
# musteri_tipi               object
# teslimat_gunu             float64
# musteri_puani             float64
# iade_durumu                object
# kar_marji_orani           float64
# toplam_tutar              float64
# dtype: object

# %%
#5.Tarih sütunundan yeni özelliklerin üretilmesi
#zaman bazlı analizlerde yıl,ay,gün ve hafta günü bilgilerini üretiyoruz
df["siparis_yili"] = df["siparis_tarihi"].dt.year
df["siparis_ayi"] = df["siparis_tarihi"].dt.month
df["siparis_gunu"] = df["siparis_tarihi"].dt.day
df["haftanin_gunu"] = df["siparis_tarihi"].dt.day_name()
df.head()
# Out:
#   siparis_id musteri_id      siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391 2024-01-13 17:06:00   İstanbul            Marmara
# 1  SIP100837    MUS1347 2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu
# 2  SIP100050    MUS1066 2025-06-03 12:42:00    Kayseri         İç Anadolu
# 3  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya            Akdeniz
# 4  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
#
#      kategori              urun_adi  adet  birim_fiyat  indirim_orani  ...  \
# 0    Kozmetik          Nemlendirici     1       414.51           0.05  ...
# 1        Spor           Dambıl Seti     2      1475.15           0.10  ...
# 2       Kitap  İş Analitiği Rehberi     1       289.02           0.05  ...
# 3       Kitap          Girişimcilik     5       194.78           0.00  ...
# 4  Elektronik             Powerbank     3       841.80           0.05  ...
#
#    musteri_tipi teslimat_gunu musteri_puani  iade_durumu  kar_marji_orani  \
# 0          Yeni           3.0           5.0        Hayır            0.220
# 1           VIP           4.0           1.0        Hayır            0.361
# 2        Mevcut           6.0           2.0        Hayır            0.348
# 3          Yeni           3.0           5.0        Hayır            0.250
# 4        Mevcut           4.0           5.0        Hayır            0.280
#
#   toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  haftanin_gunu
# 0       443.68          2024            1            13       Saturday
# 1      2685.17          2025            3            17         Monday
# 2       304.47          2025            6             3        Tuesday
# 3      1023.80          2024            8            10       Saturday
# 4      2439.03          2024            8            19         Monday
#
# [5 rows x 22 columns]

# %%
#6.kategorik sütunları category tipine dönüştürme
kategorik_donusum_sutunlari=[
    "sehir",
    "kategori",
    "urun_adi",
    "odeme_turu",
    "musteri_tipi",
    "haftanin_gunu"
]

# %%
for sutun in kategorik_donusum_sutunlari:
  df[sutun]=df[sutun].astype("category")

# %%
df.dtypes
# Out:
# siparis_id                 object
# musteri_id                 object
# siparis_tarihi     datetime64[ns]
# sehir                    category
# bolge                      object
# kategori                 category
# urun_adi                 category
# adet                        int64
# birim_fiyat               float64
# indirim_orani             float64
# kargo_ucreti              float64
# odeme_turu               category
# musteri_tipi             category
# teslimat_gunu             float64
# musteri_puani             float64
# iade_durumu                object
# kar_marji_orani           float64
# toplam_tutar              float64
# siparis_yili                int32
# siparis_ayi                 int32
# siparis_gunu                int32
# haftanin_gunu            category
# dtype: object

# %%
 #8.Güncellenmiş veri setini kaydetme
df.to_csv("e_ticaret_veri_seti_veri_tipleri_duzenlendi.csv")

# %% [markdown]
# #**Tekrarlayan ve Tutarsız Kayıtlar**
#
# Amaç:
#
# 1.   Veri setindeki tekrarlayan ve tutarsız kayıtları tespit edip temizlemek
# 2.   Eğitimde kullanılacak güncel veri setini kaydetmek
#
# Adımlar:
#
# 1.   Veri setini yüklemek
# 2.   Tekrarlayan kayıtları tespit etmek
# 3.   Tekrarlayan kayıtları incelemek
# 4.   Tekrarlayan kayıtları temizlemek
# 5.   Tutarsız kategorik değerleri incelemek
# 6.   Şehir sütunundaki tutarsız değerleri düzeltmek
# 7.   Kategori sütunundaki tutarsız değerleri düzeltmek
# 8.   Ödeme türü sütunundaki tutarsız değerleri düzeltmek
# 9.   Müşteri tipi sütunundaki tutarsız değerleri düzeltmek
# 10.  Mantıksal olarak hatalı kayıtları incele
# 11.  Mantıksal olarak hatalı kayıtları temizleme
# 12.  Güncellenmiş veri setini kaydet

# %%
# 1. Veri setini yükleme
df = pd.read_csv("e_ticaret_veri_seti_veri_tipleri_duzenlendi.csv")
df.shape
# Out:
# (1428, 23)

# %%
#2.Tekrarlayan kayıtları tespit et
tekrarlayan_kayitlar=df[df.duplicated()]
len(tekrarlayan_kayitlar)
# Out:
# 0

# %%
#3.Tekrarlayan kayıtları incele
tekrarlayan_kayitlar.head(5)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, siparis_id, musteri_id, siparis_tarihi, sehir, bolge, kategori, urun_adi, adet, birim_fiyat, indirim_orani, kargo_ucreti, odeme_turu, musteri_tipi, teslimat_gunu, musteri_puani, iade_durumu, kar_marji_orani, toplam_tutar, siparis_yili, siparis_ayi, siparis_gunu, haftanin_gunu]
# Index: []
#
# [0 rows x 23 columns]

# %%
df = pd.read_csv("e_ticaret_veri_seti_veri_tipleri_duzenlendi.csv")
#4.Tekrarlayan kayıtları temizleme
df=df.drop_duplicates()
df.shape
# Out:
# (1428, 23)

# %%
#5.Tutarsız değerleri incelenmesi
df["sehir"].unique()
# Out:
# array(['İstanbul', 'Gaziantep', 'Kayseri', 'Antalya', 'Konya', 'Ankara',
#        'Bursa', 'Trabzon', 'Adana', 'Mersin', 'Kocaeli', 'İzmir',
#        'Eskişehir', 'Samsun', nan, 'istanbul', 'ankara', 'Istanbul',
#        'gaziantep', 'Izmir'], dtype=object)

# %%
df["kategori"].unique()
# Out:
# array(['Kozmetik', 'Spor', 'Kitap', 'Elektronik', 'Ofis', 'ofis',
#        'Ev ve Yaşam', 'Elektronik ', 'spor', 'kozmetık', 'ev ve yaşam',
#        'kitap', 'Kozmetik ', 'elektronik', 'Ev&Yaşam'], dtype=object)

# %%
df["odeme_turu"].unique()
# Out:
# array(['Kredi Kartı', 'Banka Kartı', 'Kapıda Ödeme', 'Dijital Cüzdan',
#        'Havale/EFT', nan, 'Kart', 'kredi kartı', 'dijital cüzdan', 'eft',
#        'banka karti', 'Kapida Odeme', 'Havale'], dtype=object)

# %%
df["musteri_tipi"].unique()
# Out:
# array(['Yeni', 'VIP', 'Mevcut', nan, 'yeni', 'Vip', 'mevcut', 'vip'],
#       dtype=object)

# %%
#yardımcı fonksiyon:metinleri normalize edelim
#büyük küçük harf dönüşümleri,boşlukların kaldırılması, Türkçe karakter kaynaklı farkların düzenlenmesi
def metin_normalize_et(series):

  return(
      series.astype(str)
      .str.strip()
      .str.lower()
      .str.replace("i̇", "i", regex=False)
      .str.replace("ı", "i", regex=False)
      .str.replace("ö", "o", regex=False)
      .str.replace("ü", "u", regex=False)
      .str.replace("ç", "c", regex=False)
      .str.replace("ş", "s", regex=False)
      .str.replace("ğ", "g", regex=False)
  )

# %%
# 6. şehir sütunundaki tutarsız değerleri düzeltme
df["sehir"] = metin_normalize_et(df["sehir"])
df["sehir"].unique()
# Out:
# array(['istanbul', 'gaziantep', 'kayseri', 'antalya', 'konya', 'ankara',
#        'bursa', 'trabzon', 'adana', 'mersin', 'kocaeli', 'izmir',
#        'eskisehir', 'samsun', 'nan'], dtype=object)

# %%
sehir_duzeltme_haritasi = {
    "istanbul": "İstanbul",
    "ankara": "Ankara",
    "izmir": "İzmir",
    "antalya": "Antalya",
    "konya": "Konya",
    "bursa": "Bursa",
    "adana": "Adana",
    "gaziantep": "Gaziantep",
    "mersin": "Mersin",
    "kayseri": "Kayseri",
    "eskisehir": "Eskişehir",
    "samsun": "Samsun",
    "trabzon": "Trabzon",
    "kocaeli": "Kocaeli"
}
df["sehir"] = df["sehir"].replace(sehir_duzeltme_haritasi)
df["sehir"].unique()
# Out:
# array(['İstanbul', 'Gaziantep', 'Kayseri', 'Antalya', 'Konya', 'Ankara',
#        'Bursa', 'Trabzon', 'Adana', 'Mersin', 'Kocaeli', 'İzmir',
#        'Eskişehir', 'Samsun', 'nan'], dtype=object)

# %%
# 7. kategori sütunundaki tutarsız değerleri düzeltme
df["kategori"] = metin_normalize_et(df["kategori"])
df["kategori"].unique()
# Out:
# array(['kozmetik', 'spor', 'kitap', 'elektronik', 'ofis', 'ev ve yasam',
#        'ev&yasam'], dtype=object)

# %%
kategori_duzeltme_haritasi = {
    "elektronik": "Elektronik",
    "kitap": "Kitap",
    "kozmetik": "Kozmetik",
    "kozmetık": "Kozmetik",
    "spor": "Spor",
    "ev yasam": "Ev Yaşam",
    "ev ve yasam": "Ev Yaşam",
    "ev&yasam": "Ev Yaşam",
    "ofis": "Ofis"
}
df["kategori"] = df["kategori"].replace(kategori_duzeltme_haritasi)
df["kategori"].unique()
# Out:
# array(['Kozmetik', 'Spor', 'Kitap', 'Elektronik', 'Ofis', 'Ev Yaşam'],
#       dtype=object)

# %%
# 8. ödeme türü sütunundaki tutarsız değerleri düzeltelim
df["odeme_turu"] = metin_normalize_et(df["odeme_turu"])
df["odeme_turu"].unique()
# Out:
# array(['kredi karti', 'banka karti', 'kapida odeme', 'dijital cuzdan',
#        'havale/eft', 'nan', 'kart', 'eft', 'havale'], dtype=object)

# %%
odeme_turu_duzeltme_haritasi = {
    "kredi karti": "Kredi Kartı",
    "kart": "Kredi Kartı",
    "banka karti": "Banka Kartı",
    "dijital cuzdan": "Dijital Cüzdan",
    "kapida odeme": "Kapıda Ödeme",
    "havale": "Havale/EFT",
    "eft": "Havale/EFT",
    "havale/eft": "Havale/EFT"
}
df["odeme_turu"] = df["odeme_turu"].replace(odeme_turu_duzeltme_haritasi)
df["odeme_turu"].unique()
# Out:
# array(['Kredi Kartı', 'Banka Kartı', 'Kapıda Ödeme', 'Dijital Cüzdan',
#        'Havale/EFT', 'nan'], dtype=object)

# %%
# 9. müşteri tipi sütunundaki tutarsız değerleri düzeltelim
df["musteri_tipi"] = metin_normalize_et(df["musteri_tipi"])
df["musteri_tipi"].unique()
# Out:
# array(['yeni', 'vip', 'mevcut', 'nan'], dtype=object)

# %%
musteri_tipi_duzeltme_haritasi = {
    "mevcut": "Mevcut",
    "yeni": "Yeni",
    "vip": "VIP"
}
df["musteri_tipi"] = df["musteri_tipi"].replace(musteri_tipi_duzeltme_haritasi)
df["musteri_tipi"].unique()
# Out:
# array(['Yeni', 'VIP', 'Mevcut', 'nan'], dtype=object)

# %%
df["musteri_tipi"].value_counts()
# Out:
# musteri_tipi
# Mevcut    690
# Yeni      529
# VIP       167
# nan        42
# Name: count, dtype: int64

# %%
# 10. mantıksal olarak hatalı kayıtları inceleme
# negatif yada anlamsız değerler bazı kayıtlarda veri kalitesini düşürebilir
hatali_kayitlar = df[
    (df["adet"] <= 0) |
    (df["toplam_tutar"] <= 0) |
    (df["birim_fiyat"] <= 0) |
    (df["teslimat_gunu"] < 0) |
    (df["musteri_puani"] < 0) |
    (df["musteri_puani"] > 5)
]
len(hatali_kayitlar)
# Out:
# 2

# %%
pd.set_option("display.max_columns", None)
hatali_kayitlar
# Out:
#       Unnamed: 0 siparis_id musteri_id       siparis_tarihi     sehir  \
# 609          609  SIP100095    MUS1165  2025-10-12 21:31:00  İstanbul
# 1008        1008  SIP101290    MUS1225  2024-01-16 21:46:00   Kocaeli
#
#         bolge  kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 609   Marmara  Kozmetik             Şampuan     2       190.17           0.10
# 1008  Marmara  Kozmetik  Yüz Temizleme Jeli     2       303.82           0.05
#
#       kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 609            0.0  Dijital Cüzdan       Mevcut            3.0            6.0
# 1008          29.9     Kredi Kartı         Yeni            5.0            7.0
#
#      iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 609        Hayır            0.416        342.31          2025           10
# 1008        Evet            0.287        607.16          2024            1
#
#       siparis_gunu haftanin_gunu
# 609             12        Sunday
# 1008            16       Tuesday

# %%
# 11. mantıksal hataları temizleyelim
df = df[
    (df["adet"] > 0) &
    (df["toplam_tutar"] > 0) &
    (df["birim_fiyat"] > 0) &
    (df["teslimat_gunu"] >= 0) &
    (df["musteri_puani"] >= 0) &
    (df["musteri_puani"] <= 5)
]
df.shape
# Out:
# (1342, 23)

# %%
# 12. güncellenmiş verinini kaydedilmesi
df.to_csv("e_ticaret_veri_seti_tekrarlayan_kayitlar_duzenlendi.csv")

# %% [markdown]
# # **Aykırı Değerler (Outliers)**
#
# Amaç:
#
# 1.   Veri setindeki aykırı değerlerin tespit edilmesi ve incelenmesi
# 2.   Aykırı değerleri temizleyerek güncel veri setinin oluşturulması
#
# Adımlar:
#
# 1.   Veri setini yükle
# 2.   Sayısal sütunları belirle
# 3.   Sayısal sütunların özet istatistiklerini hesapla
# 4.   IQR ile aykırı değer sınırlarını hesapla
# 5.   Aykırı değer içeren kayıtları tespit etmek
# 6.   Aykırı değer sayılarını sütun bazında incelemek
# 7.   Aykırı değer içeren kayıtları veri setinden temizlemek
# 8.   Temizlenmiş veri setini kaydetmek

# %%
#1.Veri setini yüklemek
df = pd.read_csv("e_ticaret_veri_seti_tekrarlayan_kayitlar_duzenlendi.csv")

# %%
#2.Sayısal sütunların belirlenmesi
sayisal_sutunlar = df.select_dtypes(include = ["int64", "float64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['Unnamed: 0.1',
#  'Unnamed: 0',
#  'adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar',
#  'siparis_yili',
#  'siparis_ayi',
#  'siparis_gunu']

# %%
#3.sayısal sütunların özet istatistiklerini inceleyelim
df[sayisal_sutunlar].describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0         adet   birim_fiyat  indirim_orani  \
# count   1342.000000  1342.000000  1342.000000   1342.000000    1326.000000
# mean     712.452310   712.452310     2.122206    669.145961       0.052413
# std      413.403004   413.403004     1.944793   1067.583282       0.060234
# min        0.000000     0.000000     1.000000     93.660000       0.000000
# 25%      354.250000   354.250000     1.000000    199.795000       0.000000
# 50%      713.500000   713.500000     2.000000    287.735000       0.050000
# 75%     1069.750000  1069.750000     3.000000    830.052500       0.100000
# max     1427.000000  1427.000000    38.000000  18145.230000       0.200000
#
#        kargo_ucreti  teslimat_gunu  musteri_puani  kar_marji_orani  \
# count   1342.000000    1342.000000    1342.000000      1342.000000
# mean      39.743294       3.374814       3.989568         0.302756
# std       14.168266       1.837644       1.097708         0.069967
# min        0.000000       1.000000       0.000000         0.180000
# 25%       29.900000       2.000000       3.000000         0.244000
# 50%       39.900000       3.000000       4.000000         0.305000
# 75%       49.900000       4.000000       5.000000         0.362000
# max       59.900000      31.000000       5.000000         0.420000
#
#        toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu
# count   1342.000000   1342.000000  1342.000000   1342.000000
# mean    1380.023666   2024.533532     6.397914     15.638599
# std     2996.499891      0.499060     3.461250      8.712994
# min       89.680000   2024.000000     1.000000      1.000000
# 25%      323.405000   2024.000000     3.000000      8.000000
# 50%      666.535000   2025.000000     6.000000     15.000000
# 75%     1423.067500   2025.000000     9.000000     23.000000
# max    63870.200000   2025.000000    12.000000     31.000000

# %%
"""birim_fiyat
  IQR = Q3(75%) - Q1(25%)
      = 817 - 198 = 619
  Üst sınır = Q3 + k*IQR
  Alt sınır = Q1 - k*IQR
    k = 1 olsun
    Üst sınır = 817 + 619 = 1436
    Alt sınır = 198 - 619 = -421
  Outlier = üst sınır ve alt sınır dışında kalan örnekler
"""
# Out:
# 'birim_fiyat\n  IQR = Q3(75%) - Q1(25%)\n      = 817 - 198 = 619\n  Üst sınır = Q3 + k*IQR\n  Alt sınır = Q1 - k*IQR\n    k = 1 olsun\n    Üst sınır = 817 + 619 = 1436\n    Alt sınır = 198 - 619 = -421\n  Outlier = üst sınır ve alt sınır dışında kalan örnekler\n'

# %%
#4.IQR ile aykırı değer sınırlarını hesapla
aykiri_sinirlar = {}

for sutun in sayisal_sutunlar:

  q1 = df[sutun].quantile(0.25)
  q3 = df[sutun].quantile(0.75)

  iqr = q3 - q1
  alt_sinir = q1 - 1.5 * iqr
  ust_sinir = q3 + 1.5 * iqr

  aykiri_sinirlar[sutun] = {
      "q1": q1,
      "q3": q3,
      "iqr": iqr,
      "alt_sinir": alt_sinir,
      "ust_sinir": ust_sinir
  }
aykiri_sinirlar
# Out:
# {'Unnamed: 0.1': {'q1': np.float64(354.25),
#   'q3': np.float64(1069.75),
#   'iqr': np.float64(715.5),
#   'alt_sinir': np.float64(-719.0),
#   'ust_sinir': np.float64(2143.0)},
#  'Unnamed: 0': {'q1': np.float64(354.25),
#   'q3': np.float64(1069.75),
#   'iqr': np.float64(715.5),
#   'alt_sinir': np.float64(-719.0),
#   'ust_sinir': np.float64(2143.0)},
#  'adet': {'q1': np.float64(1.0),
#   'q3': np.float64(3.0),
#   'iqr': np.float64(2.0),
#   'alt_sinir': np.float64(-2.0),
#   'ust_sinir': np.float64(6.0)},
#  'birim_fiyat': {'q1': np.float64(199.79500000000002),
#   'q3': np.float64(830.0525),
#   'iqr': np.float64(630.2574999999999),
#   'alt_sinir': np.float64(-745.59125),
#   'ust_sinir': np.float64(1775.4387499999998)},
#  'indirim_orani': {'q1': np.float64(0.0),
#   'q3': np.float64(0.1),
#   'iqr': np.float64(0.1),
#   'alt_sinir': np.float64(-0.15000000000000002),
#   'ust_sinir': np.float64(0.25)},
#  'kargo_ucreti': {'q1': np.float64(29.9),
#   'q3': np.float64(49.9),
#   'iqr': np.float64(20.0),
#   'alt_sinir': np.float64(-0.10000000000000142),
#   'ust_sinir': np.float64(79.9)},
#  'teslimat_gunu': {'q1': np.float64(2.0),
#   'q3': np.float64(4.0),
#   'iqr': np.float64(2.0),
#   'alt_sinir': np.float64(-1.0),
#   'ust_sinir': np.float64(7.0)},
#  'musteri_puani': {'q1': np.float64(3.0),
#   'q3': np.float64(5.0),
#   'iqr': np.float64(2.0),
#   'alt_sinir': np.float64(0.0),
#   'ust_sinir': np.float64(8.0)},
#  'kar_marji_orani': {'q1': np.float64(0.244),
#   'q3': np.float64(0.362),
#   'iqr': np.float64(0.118),
#   'alt_sinir': np.float64(0.067),
#   'ust_sinir': np.float64(0.5389999999999999)},
#  'toplam_tutar': {'q1': np.float64(323.405),
#   'q3': np.float64(1423.0674999999999),
#   'iqr': np.float64(1099.6625),
#   'alt_sinir': np.float64(-1326.08875),
#   'ust_sinir': np.float64(3072.5612499999997)},
#  'siparis_yili': {'q1': np.float64(2024.0),
#   'q3': np.float64(2025.0),
#   'iqr': np.float64(1.0),
#   'alt_sinir': np.float64(2022.5),
#   'ust_sinir': np.float64(2026.5)},
#  'siparis_ayi': {'q1': np.float64(3.0),
#   'q3': np.float64(9.0),
#   'iqr': np.float64(6.0),
#   'alt_sinir': np.float64(-6.0),
#   'ust_sinir': np.float64(18.0)},
#  'siparis_gunu': {'q1': np.float64(8.0),
#   'q3': np.float64(23.0),
#   'iqr': np.float64(15.0),
#   'alt_sinir': np.float64(-14.5),
#   'ust_sinir': np.float64(45.5)}}

# %%
#5.aykırı değer içeren kayıtları tespit et
aykiri_maskesi=pd.Series(False,index=df.index)
for sutun in sayisal_sutunlar:
  alt_sinir = aykiri_sinirlar[sutun]["alt_sinir"]
  ust_sinir = aykiri_sinirlar[sutun]["ust_sinir"]

  sutun_maskesi = (df[sutun] < alt_sinir) | (df[sutun] > ust_sinir)
  aykiri_maskesi = aykiri_maskesi | sutun_maskesi


aykiri_kayitlar = df[aykiri_maskesi]
aykiri_kayitlar
# Out:
#       Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id       siparis_tarihi  \
# 7                7           7  SIP101172    MUS1357  2024-07-22 13:26:00
# 8                8           8  SIP100779    MUS1354  2025-12-05 11:19:00
# 15              15          15  SIP100598    MUS1223  2025-08-08 19:03:00
# 18              18          18  SIP101277    MUS1287  2024-07-31 17:52:00
# 23              24          24  SIP101061    MUS1294  2024-05-04 15:41:00
# ...            ...         ...        ...        ...                  ...
# 1328          1413        1413  SIP101388    MUS1429  2025-08-23 19:23:00
# 1329          1414        1414  SIP100060    MUS1197  2024-10-05 13:20:00
# 1330          1415        1415  SIP101246    MUS1394  2024-09-14 10:22:00
# 1333          1419        1419  SIP101279    MUS1149  2024-08-24 08:38:00
# 1339          1425        1425  SIP101210    MUS1122  2025-03-07 09:07:00
#
#          sehir       bolge    kategori           urun_adi  adet  birim_fiyat  \
# 7       Ankara  İç Anadolu        Ofis     Mekanik Klavye     3      2344.47
# 8     İstanbul     Marmara       Kitap     Python Notları     4       219.14
# 15    İstanbul     Marmara  Elektronik        Akıllı Saat     3      2889.29
# 18       Konya  İç Anadolu        Spor        Dambıl Seti     2      1618.73
# 23    İstanbul     Marmara  Elektronik  Kablosuz Kulaklık     3      1445.43
# ...        ...         ...         ...                ...   ...          ...
# 1328   Kayseri  İç Anadolu        Ofis     Mekanik Klavye     3      2341.22
# 1329  İstanbul     Marmara        Ofis     Mekanik Klavye     4      1978.74
# 1330     Adana     Akdeniz  Elektronik  Kablosuz Kulaklık     3      1496.83
# 1333    Ankara  İç Anadolu  Elektronik        Akıllı Saat     4      3074.80
# 1339       NaN     Marmara  Elektronik             Webcam     4       894.47
#
#       indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  \
# 7              0.00          59.9     Kredi Kartı       Mevcut            3.0
# 8              0.00          29.9     Kredi Kartı         Yeni           18.0
# 15             0.00          39.9     Banka Kartı         Yeni            1.0
# 18             0.05          29.9     Kredi Kartı         Yeni            3.0
# 23             0.00          39.9     Banka Kartı       Mevcut            4.0
# ...             ...           ...             ...          ...            ...
# 1328           0.05          39.9     Kredi Kartı          VIP            2.0
# 1329           0.00          49.9  Dijital Cüzdan         Yeni            6.0
# 1330           0.15          39.9  Dijital Cüzdan       Mevcut            4.0
# 1333           0.15          39.9     Banka Kartı         Yeni            4.0
# 1339           0.10          49.9     Kredi Kartı       Mevcut            3.0
#
#       musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  \
# 7               4.0       Hayır            0.312       7093.31          2024
# 8               5.0        Evet            0.408        906.46          2025
# 15              1.0       Hayır            0.189       8707.77          2025
# 18              5.0       Hayır            0.208       3105.49          2024
# 23              4.0        Evet            0.407       4376.19          2024
# ...             ...         ...              ...           ...           ...
# 1328            4.0       Hayır            0.318       6712.38          2025
# 1329            5.0       Hayır            0.216       7964.86          2024
# 1330            5.0       Hayır            0.248       3856.82          2024
# 1333            5.0       Hayır            0.414      10494.22          2024
# 1339            5.0       Hayır            0.355       3269.99          2025
#
#       siparis_ayi  siparis_gunu haftanin_gunu
# 7               7            22        Monday
# 8              12             5        Friday
# 15              8             8        Friday
# 18              7            31     Wednesday
# 23              5             4      Saturday
# ...           ...           ...           ...
# 1328            8            23      Saturday
# 1329           10             5      Saturday
# 1330            9            14      Saturday
# 1333            8            24      Saturday
# 1339            3             7        Friday
#
# [156 rows x 24 columns]

# %%
#Aykırı değer sayılarını sütun bazında inceleme
for sutun in sayisal_sutunlar:
  alt_sinir=aykiri_sinirlar[sutun]["alt_sinir"]
  ust_sinir=aykiri_sinirlar[sutun]["ust_sinir"]
  aykiri_sayi=((df[sutun] < alt_sinir) | (df[sutun] > ust_sinir)).sum()
  print(f"{sutun}:{aykiri_sayi}")
# Out:
# Unnamed: 0.1:0
# Unnamed: 0:0
# adet:5
# birim_fiyat:90
# indirim_orani:0
# kargo_ucreti:0
# teslimat_gunu:6
# musteri_puani:0
# kar_marji_orani:0
# toplam_tutar:120
# siparis_yili:0
# siparis_ayi:0
# siparis_gunu:0

# %%
# 7. aykırı değer içeren kayıtları veri setinden temizleme
df_temiz = df[~aykiri_maskesi].copy()
df_temiz.shape
# Out:
# (1186, 24)

# %%
#8.Temizlenmiş veri setini kaydet
df_temiz.to_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")

# %% [markdown]
# # **Kategorik Veri Analizi**
#
# Amaç:
#
# 1.   Veri setindeki kategorik sütunları incelemek ve dağılımlarını analiz etmek
# 2.   Frekans,oran ve görselleştirme yöntemleri ile kategorik verileri yorumlama
#
# Adımlar:
#
# 1.   Veri setini yüklemek
# 2.   Kategorik sütunları belirlemek
# 3.   Kategorik sütunların genel bilgisini incelemek
# 4.   Her kategorik sütun için frekans analizi yapmak
# 5.   Her kategorik sütun için oran analizi yapmak
# 6.   En sık görülen kategorileri incele
# 7.   En az görülen kategorileri incele
# 8.   Belirli sütunlar üzerinde detaylı kategorik analiz
# 9.   Belirli sütunlar için count plot çizdirme

# %%
import matplotlib.pyplot as plt # görselleştirme
import seaborn as sns # görselleştirme

# %%
# 1. veri setini yükleme
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")

# %%
# 2. kategorik sütunları belirle
kategorik_sutunlar = df.select_dtypes(include = ["object", "category"]).columns.tolist()
kategorik_sutunlar
# Out:
# ['siparis_id',
#  'musteri_id',
#  'siparis_tarihi',
#  'sehir',
#  'bolge',
#  'kategori',
#  'urun_adi',
#  'odeme_turu',
#  'musteri_tipi',
#  'iade_durumu',
#  'haftanin_gunu']

# %%
# 3.kategorik sutunların genel bilgisinin incelenmesi
for sutun in kategorik_sutunlar:
  print(f"sutun adı: {sutun}")
  print(f"veri tipi: {df[sutun].dtype}")
  print(f"benzersiz deger sayısı: {df[sutun].nunique()}")
  print()
# Out:
# sutun adı: siparis_id
# veri tipi: object
# benzersiz deger sayısı: 1161
#
# sutun adı: musteri_id
# veri tipi: object
# benzersiz deger sayısı: 413
#
# sutun adı: siparis_tarihi
# veri tipi: object
# benzersiz deger sayısı: 1159
#
# sutun adı: sehir
# veri tipi: object
# benzersiz deger sayısı: 14
#
# sutun adı: bolge
# veri tipi: object
# benzersiz deger sayısı: 6
#
# sutun adı: kategori
# veri tipi: object
# benzersiz deger sayısı: 6
#
# sutun adı: urun_adi
# veri tipi: object
# benzersiz deger sayısı: 28
#
# sutun adı: odeme_turu
# veri tipi: object
# benzersiz deger sayısı: 5
#
# sutun adı: musteri_tipi
# veri tipi: object
# benzersiz deger sayısı: 3
#
# sutun adı: iade_durumu
# veri tipi: object
# benzersiz deger sayısı: 2
#
# sutun adı: haftanin_gunu
# veri tipi: object
# benzersiz deger sayısı: 7

# %%
#4.her kategorik sütun için frekans analizi yapalım
for sutun in kategorik_sutunlar:
  print(df[sutun].value_counts())
  print()
# Out:
# siparis_id
# SIP100707    2
# SIP100725    2
# SIP100533    2
# SIP101042    2
# SIP100209    2
#             ..
# SIP101260    1
# SIP100413    1
# SIP100963    1
# SIP100856    1
# SIP100021    1
# Name: count, Length: 1161, dtype: int64
#
# musteri_id
# MUS1360    9
# MUS1204    8
# MUS1433    8
# MUS1435    8
# MUS1289    7
#           ..
# MUS1443    1
# MUS1361    1
# MUS1335    1
# MUS1088    1
# MUS1425    1
# Name: count, Length: 413, dtype: int64
#
# siparis_tarihi
# 2025-10-26 10:41:00    2
# 2025-05-24 10:10:00    2
# 2024-11-19 14:22:00    2
# 2025-06-10 20:32:00    2
# 2024-06-20 20:34:00    2
#                       ..
# 2025-02-01 17:25:00    1
# 2024-08-24 12:47:00    1
# 2024-02-10 10:36:00    1
# 2024-07-26 17:34:00    1
# 2024-09-03 13:17:00    1
# Name: count, Length: 1159, dtype: int64
#
# sehir
# İstanbul     256
# Ankara       143
# İzmir        130
# Antalya       86
# Konya         78
# Bursa         70
# Adana         70
# Gaziantep     56
# Trabzon       51
# Samsun        48
# Eskişehir     46
# Mersin        46
# Kayseri       45
# Kocaeli       40
# Name: count, dtype: int64
#
# bolge
# Marmara              374
# İç Anadolu           315
# Akdeniz              203
# Ege                  135
# Karadeniz            102
# Güneydoğu Anadolu     57
# Name: count, dtype: int64
#
# kategori
# Kitap         239
# Kozmetik      212
# Spor          206
# Ev Yaşam      202
# Ofis          170
# Elektronik    157
# Name: count, dtype: int64
#
# urun_adi
# Veri Bilimi 101         52
# Suluk                   52
# Powerbank               51
# Not Tutucu              49
# Saklama Kutusu          49
# Zaman Yönetimi          49
# Python Notları          48
# Direnç Bandı            46
# İş Analitiği Rehberi    45
# Girişimcilik            45
# Şampuan                 44
# Nemlendirici            43
# Defter Seti             43
# Güneş Kremi             42
# Yüz Temizleme Jeli      42
# Kahve Kupası            42
# Mouse Pad               42
# Serum                   41
# Spor Çantası            40
# Organizer               39
# Webcam                  39
# Yoga Matı               37
# Bluetooth Hoparlör      36
# Kalem Seti              36
# Masa Lambası            36
# Termos                  36
# Dambıl Seti             31
# Kablosuz Kulaklık       31
# Name: count, dtype: int64
#
# odeme_turu
# Kredi Kartı       588
# Banka Kartı       195
# Dijital Cüzdan    166
# Havale/EFT        121
# Kapıda Ödeme       87
# Name: count, dtype: int64
#
# musteri_tipi
# Mevcut    571
# Yeni      445
# VIP       137
# Name: count, dtype: int64
#
# iade_durumu
# Hayır    1088
# Evet       98
# Name: count, dtype: int64
#
# haftanin_gunu
# Saturday     186
# Tuesday      183
# Thursday     174
# Friday       163
# Sunday       163
# Wednesday    163
# Monday       154
# Name: count, dtype: int64

# %%
# 5. her kategorik sütun için oran analizi yapalım
for sutun in kategorik_sutunlar:
  print((df[sutun].value_counts(normalize = True) * 100).round(2))
  print()
# Out:
# siparis_id
# SIP100707    0.17
# SIP100725    0.17
# SIP100533    0.17
# SIP101042    0.17
# SIP100209    0.17
#              ...
# SIP101260    0.08
# SIP100413    0.08
# SIP100963    0.08
# SIP100856    0.08
# SIP100021    0.08
# Name: proportion, Length: 1161, dtype: float64
#
# musteri_id
# MUS1360    0.76
# MUS1204    0.67
# MUS1433    0.67
# MUS1435    0.67
# MUS1289    0.59
#            ...
# MUS1443    0.08
# MUS1361    0.08
# MUS1335    0.08
# MUS1088    0.08
# MUS1425    0.08
# Name: proportion, Length: 413, dtype: float64
#
# siparis_tarihi
# 2025-10-26 10:41:00    0.17
# 2025-05-24 10:10:00    0.17
# 2024-11-19 14:22:00    0.17
# 2025-06-10 20:32:00    0.17
# 2024-06-20 20:34:00    0.17
#                        ...
# 2025-02-01 17:25:00    0.08
# 2024-08-24 12:47:00    0.08
# 2024-02-10 10:36:00    0.08
# 2024-07-26 17:34:00    0.08
# 2024-09-03 13:17:00    0.08
# Name: proportion, Length: 1159, dtype: float64
#
# sehir
# İstanbul     21.97
# Ankara       12.27
# İzmir        11.16
# Antalya       7.38
# Konya         6.70
# Bursa         6.01
# Adana         6.01
# Gaziantep     4.81
# Trabzon       4.38
# Samsun        4.12
# Eskişehir     3.95
# Mersin        3.95
# Kayseri       3.86
# Kocaeli       3.43
# Name: proportion, dtype: float64
#
# bolge
# Marmara              31.53
# İç Anadolu           26.56
# Akdeniz              17.12
# Ege                  11.38
# Karadeniz             8.60
# Güneydoğu Anadolu     4.81
# Name: proportion, dtype: float64
#
# kategori
# Kitap         20.15
# Kozmetik      17.88
# Spor          17.37
# Ev Yaşam      17.03
# Ofis          14.33
# Elektronik    13.24
# Name: proportion, dtype: float64
#
# urun_adi
# Veri Bilimi 101         4.38
# Suluk                   4.38
# Powerbank               4.30
# Not Tutucu              4.13
# Saklama Kutusu          4.13
# Zaman Yönetimi          4.13
# Python Notları          4.05
# Direnç Bandı            3.88
# İş Analitiği Rehberi    3.79
# Girişimcilik            3.79
# Şampuan                 3.71
# Nemlendirici            3.63
# Defter Seti             3.63
# Güneş Kremi             3.54
# Yüz Temizleme Jeli      3.54
# Kahve Kupası            3.54
# Mouse Pad               3.54
# Serum                   3.46
# Spor Çantası            3.37
# Organizer               3.29
# Webcam                  3.29
# Yoga Matı               3.12
# Bluetooth Hoparlör      3.04
# Kalem Seti              3.04
# Masa Lambası            3.04
# Termos                  3.04
# Dambıl Seti             2.61
# Kablosuz Kulaklık       2.61
# Name: proportion, dtype: float64
#
# odeme_turu
# Kredi Kartı       50.82
# Banka Kartı       16.85
# Dijital Cüzdan    14.35
# Havale/EFT        10.46
# Kapıda Ödeme       7.52
# Name: proportion, dtype: float64
#
# musteri_tipi
# Mevcut    49.52
# Yeni      38.59
# VIP       11.88
# Name: proportion, dtype: float64
#
# iade_durumu
# Hayır    91.74
# Evet      8.26
# Name: proportion, dtype: float64
#
# haftanin_gunu
# Saturday     15.68
# Tuesday      15.43
# Thursday     14.67
# Friday       13.74
# Sunday       13.74
# Wednesday    13.74
# Monday       12.98
# Name: proportion, dtype: float64

# %%
# 6. en sık görülen kategorileri incele
for sutun in kategorik_sutunlar:
  print()
  print(df[sutun].value_counts().head(3))
# Out:
# siparis_id
# SIP100707    2
# SIP100725    2
# SIP100533    2
# Name: count, dtype: int64
#
# musteri_id
# MUS1360    9
# MUS1204    8
# MUS1433    8
# Name: count, dtype: int64
#
# siparis_tarihi
# 2025-10-26 10:41:00    2
# 2025-05-24 10:10:00    2
# 2024-11-19 14:22:00    2
# Name: count, dtype: int64
#
# sehir
# İstanbul    256
# Ankara      143
# İzmir       130
# Name: count, dtype: int64
#
# bolge
# Marmara       374
# İç Anadolu    315
# Akdeniz       203
# Name: count, dtype: int64
#
# kategori
# Kitap       239
# Kozmetik    212
# Spor        206
# Name: count, dtype: int64
#
# urun_adi
# Veri Bilimi 101    52
# Suluk              52
# Powerbank          51
# Name: count, dtype: int64
#
# odeme_turu
# Kredi Kartı       588
# Banka Kartı       195
# Dijital Cüzdan    166
# Name: count, dtype: int64
#
# musteri_tipi
# Mevcut    571
# Yeni      445
# VIP       137
# Name: count, dtype: int64
#
# iade_durumu
# Hayır    1088
# Evet       98
# Name: count, dtype: int64
#
# haftanin_gunu
# Saturday    186
# Tuesday     183
# Thursday    174
# Name: count, dtype: int64

# %%
# 7. en az görülen kategorileri incele
for sutun in kategorik_sutunlar:
  print()
  print(df[sutun].value_counts().tail(3))
# Out:
# siparis_id
# SIP100963    1
# SIP100856    1
# SIP100021    1
# Name: count, dtype: int64
#
# musteri_id
# MUS1335    1
# MUS1088    1
# MUS1425    1
# Name: count, dtype: int64
#
# siparis_tarihi
# 2024-02-10 10:36:00    1
# 2024-07-26 17:34:00    1
# 2024-09-03 13:17:00    1
# Name: count, dtype: int64
#
# sehir
# Mersin     46
# Kayseri    45
# Kocaeli    40
# Name: count, dtype: int64
#
# bolge
# Ege                  135
# Karadeniz            102
# Güneydoğu Anadolu     57
# Name: count, dtype: int64
#
# kategori
# Ev Yaşam      202
# Ofis          170
# Elektronik    157
# Name: count, dtype: int64
#
# urun_adi
# Termos               36
# Dambıl Seti          31
# Kablosuz Kulaklık    31
# Name: count, dtype: int64
#
# odeme_turu
# Dijital Cüzdan    166
# Havale/EFT        121
# Kapıda Ödeme       87
# Name: count, dtype: int64
#
# musteri_tipi
# Mevcut    571
# Yeni      445
# VIP       137
# Name: count, dtype: int64
#
# iade_durumu
# Hayır    1088
# Evet       98
# Name: count, dtype: int64
#
# haftanin_gunu
# Sunday       163
# Wednesday    163
# Monday       154
# Name: count, dtype: int64

# %%
# 8. belirli sütunlar üzerinde detaylı kategorik analiz
detayli_analiz_sutunlari = ["sehir", "kategori", "odeme_turu", "musteri_tipi"]

for sutun in detayli_analiz_sutunlari:
  if sutun in df.columns:
    print("Frekanslar:")
    print(df[sutun].value_counts())
    print("Oranlar:")
    print((df[sutun].value_counts(normalize = True) * 100).round(2))
    print()
# Out:
# Frekanslar:
# sehir
# İstanbul     256
# Ankara       143
# İzmir        130
# Antalya       86
# Konya         78
# Bursa         70
# Adana         70
# Gaziantep     56
# Trabzon       51
# Samsun        48
# Eskişehir     46
# Mersin        46
# Kayseri       45
# Kocaeli       40
# Name: count, dtype: int64
# Oranlar:
# sehir
# İstanbul     21.97
# Ankara       12.27
# İzmir        11.16
# Antalya       7.38
# Konya         6.70
# Bursa         6.01
# Adana         6.01
# Gaziantep     4.81
# Trabzon       4.38
# Samsun        4.12
# Eskişehir     3.95
# Mersin        3.95
# Kayseri       3.86
# Kocaeli       3.43
# Name: proportion, dtype: float64
#
# Frekanslar:
# kategori
# Kitap         239
# Kozmetik      212
# Spor          206
# Ev Yaşam      202
# Ofis          170
# Elektronik    157
# Name: count, dtype: int64
# Oranlar:
# kategori
# Kitap         20.15
# Kozmetik      17.88
# Spor          17.37
# Ev Yaşam      17.03
# Ofis          14.33
# Elektronik    13.24
# Name: proportion, dtype: float64
#
# Frekanslar:
# odeme_turu
# Kredi Kartı       588
# Banka Kartı       195
# Dijital Cüzdan    166
# Havale/EFT        121
# Kapıda Ödeme       87
# Name: count, dtype: int64
# Oranlar:
# odeme_turu
# Kredi Kartı       50.82
# Banka Kartı       16.85
# Dijital Cüzdan    14.35
# Havale/EFT        10.46
# Kapıda Ödeme       7.52
# Name: proportion, dtype: float64
#
# Frekanslar:
# musteri_tipi
# Mevcut    571
# Yeni      445
# VIP       137
# Name: count, dtype: int64
# Oranlar:
# musteri_tipi
# Mevcut    49.52
# Yeni      38.59
# VIP       11.88
# Name: proportion, dtype: float64

# %%
# 9. belirli sütunlar için count plot çizdirme
for sutun in detayli_analiz_sutunlari:
  if sutun in df.columns:
    plt.figure(figsize = (6,3))
    sns.countplot(data = df, x = sutun, order = df[sutun].value_counts().index)
    plt.title(f"{sutun} sütunu için count plot")
    plt.xlabel(sutun)
    plt.ylabel("Frekans")
    plt.xticks(rotation = 45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # **Sayısal Veri Analizi**
#
# Amaç:
#
# 1.   Veri setindeki analiz için uygun sayısal sütunları incelemek
# 2.   Temel istatistikler ve histogram ile dağılım yapısını değerlendirmek
#
# Adımlar:
#
# 1.   Veri setini yüklemek
# 2.   Sayısal sütunları belirlemek
# 3.   Analiz için uygun sayısal sütunları seçmek
# 4.   Seçilen sütunların genel bilgisini incelemek
# 5.   Temel istatistikleri hesapla
# 6.   Histogram çizdir

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. veri setini yükleme
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")

# %%
# 2. sayısal tipteki sütunları belirle
sayisal_sutunlar = df.select_dtypes(include = ["int64", "float64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['Unnamed: 0.2',
#  'Unnamed: 0.1',
#  'Unnamed: 0',
#  'adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar',
#  'siparis_yili',
#  'siparis_ayi',
#  'siparis_gunu']

# %%
# 3. analiz için uygun sayısal sütunlar
analiz_sutunlari  = ["birim_fiyat", "toplam_tutar" ,"teslimat_gunu", "musteri_puani"]

# %%
# 4. seçilen sutunların genel bilgisini incele
for sutun in analiz_sutunlari:
  if sutun in df.columns:
    print(f"Sütun: {sutun}")
    print(f"Veri tipi: {df[sutun].dtype}")
    print(f"Benzersiz değer sayısı: {df[sutun].nunique()}")
    print()
# Out:
# Sütun: birim_fiyat
# Veri tipi: float64
# Benzersiz değer sayısı: 1144
#
# Sütun: toplam_tutar
# Veri tipi: float64
# Benzersiz değer sayısı: 1158
#
# Sütun: teslimat_gunu
# Veri tipi: float64
# Benzersiz değer sayısı: 7
#
# Sütun: musteri_puani
# Veri tipi: float64
# Benzersiz değer sayısı: 6

# %%
# 5. temel istatistikleri hesapla
df[analiz_sutunlari].describe()
# Out:
#        birim_fiyat  toplam_tutar  teslimat_gunu  musteri_puani
# count  1186.000000   1186.000000    1186.000000    1186.000000
# mean    446.039739    791.720548       3.324621       3.979764
# std     376.016428    651.936646       1.457708       1.103701
# min      93.660000     89.680000       1.000000       0.000000
# 25%     193.255000    293.817500       2.000000       3.000000
# 50%     260.810000    555.570000       3.000000       4.000000
# 75%     612.025000   1030.955000       4.000000       5.000000
# max    1751.140000   3071.100000       7.000000       5.000000

# %%
# 6. histogram çizdirme
for sutun in analiz_sutunlari:
  if sutun in df.columns:
    plt.figure(figsize = (6,3))
    plt.hist(df[sutun], bins = 120)
    plt.title(f"{sutun} sütunu için histogram")
    plt.xlabel(sutun)
    plt.ylabel("frekans")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # **Grup Bazlı Analiz**
#
# Amaç:
#
# 1.   Veri setini farklı kırılımlara ayırarak grup bazlı analiz yapalım
# 2.   groupby yapısı ile özet istatistikler üretip sonuçları yorumlamak
#
# Adımlar:
#
# 1.   Veri setini yüklemek
# 2.   Grup bazlı analiz için kullanılacak sütunları belirle
# 3.   Kategoriye göre temel analiz
# 4.   Şehre göre temel analiz
# 5.   Müşteri tipine göre temel analiz
# 6.   Ödeme türüne göre temel analiz
# 7.   Birden fazla sütun ile grup bazlı analiz

# %%
import pandas as pd
pd.set_option("display.max_columns", None)#bütün sütunları göster

# %%
# 1. veri setini yükleyelim
# 2. grup bazlı analiz için kullanılacak sütunları belirle
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0             0             0           0  SIP101125    MUS1391
# 1             1             1           1  SIP100837    MUS1347
# 2             2             2           2  SIP100050    MUS1066
# 3             3             3           3  SIP100263    MUS1008
# 4             4             4           4  SIP100707    MUS1291
#
#         siparis_tarihi      sehir              bolge    kategori  \
# 0  2024-01-13 17:06:00   İstanbul            Marmara    Kozmetik
# 1  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu        Spor
# 2  2025-06-03 12:42:00    Kayseri         İç Anadolu       Kitap
# 3  2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 4  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
#
#                urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0          Nemlendirici     1       414.51           0.05          49.9
# 1           Dambıl Seti     2      1475.15           0.10          29.9
# 2  İş Analitiği Rehberi     1       289.02           0.05          29.9
# 3          Girişimcilik     5       194.78           0.00          49.9
# 4             Powerbank     3       841.80           0.05          39.9
#
#        odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0     Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1     Banka Kartı          VIP            4.0            1.0       Hayır
# 2     Kredi Kartı       Mevcut            6.0            2.0       Hayır
# 3    Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 4  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
#
#    kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68          2024            1            13
# 1            0.361       2685.17          2025            3            17
# 2            0.348        304.47          2025            6             3
# 3            0.250       1023.80          2024            8            10
# 4            0.280       2439.03          2024            8            19
#
#   haftanin_gunu
# 0      Saturday
# 1        Monday
# 2       Tuesday
# 3      Saturday
# 4        Monday

# %%
# 3. kategoriye göre temel analiz
kategori_analizi = df.groupby("kategori").agg(
    {
        "toplam_tutar": ["count", "mean", "sum"],
        "birim_fiyat": "mean",
        "musteri_puani": "mean",
        "teslimat_gunu": "mean"
    }
).round(1)
kategori_analizi
# Out:
#            toplam_tutar                   birim_fiyat musteri_puani  \
#                   count    mean       sum        mean          mean
# kategori
# Elektronik          157  1548.3  243084.3      1080.2           4.0
# Ev Yaşam            202   750.5  151605.7       353.2           3.9
# Kitap               239   495.6  118439.8       224.7           4.0
# Kozmetik            212   755.8  160225.7       374.1           4.1
# Ofis                170   301.5   51252.5       141.0           3.9
# Spor                206  1040.6  214372.6       636.3           4.0
#
#            teslimat_gunu
#                     mean
# kategori
# Elektronik           3.3
# Ev Yaşam             3.5
# Kitap                3.5
# Kozmetik             3.3
# Ofis                 3.2
# Spor                 3.2

# %%
# 4. şehre göre temel analiz yapalım
sehir_analiz = df.groupby("sehir").agg(
    {
        "toplam_tutar": ["sum", "mean"],
        "teslimat_gunu": "mean",
        "musteri_puani": "mean"
    }
).round(1)
sehir_analiz
# Out:
#           toplam_tutar        teslimat_gunu musteri_puani
#                    sum   mean          mean          mean
# sehir
# Adana          55335.9  790.5           3.4           4.1
# Ankara        108223.7  756.8           3.1           3.7
# Antalya        67983.6  790.5           3.4           4.0
# Bursa          49970.1  713.9           3.6           4.0
# Eskişehir      38319.5  833.0           3.3           4.0
# Gaziantep      50587.6  903.4           3.5           4.1
# Kayseri        30997.5  688.8           3.5           3.8
# Kocaeli        27238.3  681.0           3.3           3.4
# Konya          62719.8  804.1           3.4           4.2
# Mersin         36992.9  804.2           3.3           4.1
# Samsun         38979.7  812.1           3.2           4.1
# Trabzon        38267.9  750.4           3.5           3.8
# İstanbul      221231.2  864.2           3.3           4.1
# İzmir          96967.1  745.9           3.2           3.8

# %%
# 5. müşteri tipine göre temel analiz
musteri_tipi_analiz = df.groupby("musteri_tipi").agg(
    {
        "toplam_tutar": ["sum", "mean"],
        "teslimat_gunu": "mean",
        "musteri_puani": "mean"
    }
).round(1)
musteri_tipi_analiz
# Out:
#              toplam_tutar        teslimat_gunu musteri_puani
#                       sum   mean          mean          mean
# musteri_tipi
# Mevcut           460989.7  807.3           3.4           4.0
# VIP              113818.9  830.8           3.4           3.9
# Yeni             336036.2  755.1           3.3           4.0

# %%
# 6. ödeme türüne göre temel analiz
odeme_turu_analizi = df.groupby("odeme_turu").agg(
    {
        "toplam_tutar": ["sum", "mean"],
        "teslimat_gunu": "mean",
        "musteri_puani": "mean"
    }
).round(1)
odeme_turu_analizi
# Out:
#                toplam_tutar        teslimat_gunu musteri_puani
#                         sum   mean          mean          mean
# odeme_turu
# Banka Kartı        166408.3  853.4           3.5           3.8
# Dijital Cüzdan     148542.0  894.8           3.3           4.0
# Havale/EFT         100961.4  834.4           3.1           3.9
# Kapıda Ödeme        58713.4  674.9           3.2           4.0
# Kredi Kartı        437763.6  744.5           3.3           4.1

# %%
# 7. birden fazla sütun ile grup bazlı analiz
kategori_musteri_tipi_analizi = df.groupby(["kategori", "musteri_tipi"]).agg(
    {
        "toplam_tutar": ["mean", "sum"],
        "musteri_puani": "mean",
        "teslimat_gunu": "mean"
    }
).round(1)
kategori_musteri_tipi_analizi
# Out:
#                         toplam_tutar           musteri_puani teslimat_gunu
#                                 mean       sum          mean          mean
# kategori   musteri_tipi
# Elektronik Mevcut             1639.9  134472.8           4.0           3.4
#            VIP                1370.6   30153.5           3.9           3.0
#            Yeni               1524.0   70102.2           4.0           3.3
# Ev Yaşam   Mevcut              777.9   78565.8           3.9           3.5
#            VIP                 791.3   18991.2           3.9           3.6
#            Yeni                693.6   52714.3           3.8           3.4
# Kitap      Mevcut              477.4   55373.2           4.0           3.6
#            VIP                 564.9   14123.0           3.9           3.6
#            Yeni                498.9   45400.7           4.0           3.3
# Kozmetik   Mevcut              729.7   80267.8           4.0           3.3
#            VIP                 735.9   22076.3           4.2           3.7
#            Yeni                806.3   52412.0           4.2           3.1
# Ofis       Mevcut              292.4   21051.9           4.0           3.2
#            VIP                 303.8    5467.9           3.4           2.8
#            Yeni                313.8   24161.7           4.0           3.3
# Spor       Mevcut             1014.0   91258.2           4.0           3.1
#            VIP                1278.2   23007.0           4.1           3.0
#            Yeni               1013.8   91245.3           3.9           3.2

# %% [markdown]
# # **Pivot Tablo Analizi**
#
# Amaç:
#
# 1.   Veri setini iki yönlü kırılımlar ile özetleyerek pivot tablo mantığını kavramak
# 2.   Pivot tablo ile karşılaştırmalı analizler ve sonuçların yorumlanması
#
# Adımlar:
#
# 1.   Veri setini yükle
# 2.   Kategori ve müşteri tipine göre pivot tablo analizi
# 3.   Şehir ve ödeme türüne göre pivot tablo analizi
# 4.   Kategori ve ödeme türüne göre pivot tablo analizi
# 5.   Şehir ve müşteri tipine göre pivot tablo analizi

# %%
# 1. veri setini yükle
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0             0             0           0  SIP101125    MUS1391
# 1             1             1           1  SIP100837    MUS1347
# 2             2             2           2  SIP100050    MUS1066
# 3             3             3           3  SIP100263    MUS1008
# 4             4             4           4  SIP100707    MUS1291
#
#         siparis_tarihi      sehir              bolge    kategori  \
# 0  2024-01-13 17:06:00   İstanbul            Marmara    Kozmetik
# 1  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu        Spor
# 2  2025-06-03 12:42:00    Kayseri         İç Anadolu       Kitap
# 3  2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 4  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
#
#                urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0          Nemlendirici     1       414.51           0.05          49.9
# 1           Dambıl Seti     2      1475.15           0.10          29.9
# 2  İş Analitiği Rehberi     1       289.02           0.05          29.9
# 3          Girişimcilik     5       194.78           0.00          49.9
# 4             Powerbank     3       841.80           0.05          39.9
#
#        odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0     Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1     Banka Kartı          VIP            4.0            1.0       Hayır
# 2     Kredi Kartı       Mevcut            6.0            2.0       Hayır
# 3    Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 4  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
#
#    kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68          2024            1            13
# 1            0.361       2685.17          2025            3            17
# 2            0.348        304.47          2025            6             3
# 3            0.250       1023.80          2024            8            10
# 4            0.280       2439.03          2024            8            19
#
#   haftanin_gunu
# 0      Saturday
# 1        Monday
# 2       Tuesday
# 3      Saturday
# 4        Monday

# %%
# 2. kategori ve müşteri tipine göre pivot tablo analizi
# her kategori için müşteri tiplerine göre ortalama toplam tutar
pivot_kategori_musteri = pd.pivot_table(
    df,
    index = "kategori",
    columns = "musteri_tipi",
    values = "toplam_tutar",
    aggfunc = "mean"
).round(1)
pivot_kategori_musteri
# Out:
# musteri_tipi  Mevcut     VIP    Yeni
# kategori
# Elektronik    1639.9  1370.6  1524.0
# Ev Yaşam       777.9   791.3   693.6
# Kitap          477.4   564.9   498.9
# Kozmetik       729.7   735.9   806.3
# Ofis           292.4   303.8   313.8
# Spor          1014.0  1278.2  1013.8

# %%
# 3. şehir ve ödeme türü göre pivot tablo analizi
# her kategori için müşteri tiplerine göre ortalama toplam tutar
pivot_sehir_odeme_turu = pd.pivot_table(
    df,
    index = "sehir",
    columns = "odeme_turu",
    values = "toplam_tutar",
    aggfunc = "sum"
).round(1)
pivot_sehir_odeme_turu
# Out:
# odeme_turu  Banka Kartı  Dijital Cüzdan  Havale/EFT  Kapıda Ödeme  Kredi Kartı
# sehir
# Adana            9455.7          9134.0      5565.5        5851.8      24218.3
# Ankara          16537.0         17848.9     13799.8        6811.2      52943.3
# Antalya          9986.8          8061.5      5781.2        5256.1      38205.3
# Bursa            5795.8          7424.1      7475.1        4024.1      25251.0
# Eskişehir        4507.2          6989.5      2029.2        4013.1      20780.5
# Gaziantep        8591.5         10275.6      3746.8        2853.9      24406.4
# Kayseri          5155.2          3406.8      6466.2        6119.5       9191.9
# Kocaeli          5220.6          7376.3      3373.7        4169.8       7097.8
# Konya           16606.9          9379.3      4558.2        2611.8      27839.0
# Mersin           9872.2          4307.8      2454.0           NaN      20359.0
# Samsun           5934.8          9295.9      4345.8         177.3      18456.1
# Trabzon          7006.7          3588.6      6573.0        3298.2      16125.0
# İstanbul        46890.9         34714.5     23581.4        5602.9      97839.1
# İzmir           12867.0         16499.0      9812.6        7589.3      47387.8

# %%
# 4. kategori ve ödeme türüne göre pivot tablo analizi
pivot_kategori_odeme = pd.pivot_table(
    df,
    index = "kategori",
    columns =  "odeme_turu",
    values = "musteri_puani",
    aggfunc = "mean"
).round(2)
pivot_kategori_odeme
# Out:
# odeme_turu  Banka Kartı  Dijital Cüzdan  Havale/EFT  Kapıda Ödeme  Kredi Kartı
# kategori
# Elektronik         3.80            3.86        3.95          3.50         4.18
# Ev Yaşam           3.68            3.67        3.86          4.23         3.96
# Kitap              4.00            4.00        3.92          4.29         3.98
# Kozmetik           4.00            4.33        3.53          4.59         4.14
# Ofis               3.60            4.00        3.95          3.56         4.06
# Spor               3.86            4.06        3.83          3.71         4.05

# %%
# 5. şehir ve müşteri tipi göre pivot tablo analizi
pivot_sehir_musteri = pd.pivot_table(
    df,
    index = "sehir",
    columns =  "musteri_tipi",
    values = "kargo_ucreti",
    aggfunc = "mean"
).round(2)
pivot_sehir_musteri
# Out:
# musteri_tipi  Mevcut    VIP   Yeni
# sehir
# Adana          39.91  41.90  41.26
# Ankara         41.43  39.91  40.11
# Antalya        38.41  38.24  39.30
# Bursa          37.41  36.58  38.99
# Eskişehir      36.38  43.23  36.87
# Gaziantep      38.43  43.65  42.41
# Kayseri        42.57  45.90  43.65
# Kocaeli        42.40  54.90  41.02
# Konya          37.99  35.92  39.10
# Mersin         42.82  39.90  41.02
# Samsun         40.32  39.90  36.38
# Trabzon        35.82  41.33  43.90
# İstanbul       39.74  39.33  36.61
# İzmir          41.48  37.69  37.84

# %% [markdown]
# # **Veri Görselleştirme**
#
# Amaç:
#
# 1.   Veri setindeki farklı değişkenleri uygun grafik türüyle görselleştirmek
# 2.   Grafikler üzerinden zaman değişimi, ilişki, karşılaştırma ve dağılım yapısını incelemek
#
# Adımlar:
#
# 1.   Veri setini yüklemek
# 2.   Line plot ile zaman içindeki değişimi görselleştirmek
# 3.   Scatter plot ile iki sayısal değişken arasındaki ilişkiyi görselleştirmek
# 4.   Bar plot ile karşılaştırmalı görselleştirme yapmak
# 5.   Histogram ile sayısal dağılım görselleştirmek
# 6.   Box plot ile dağılım ve aykırı değer tespiti

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme()
#seaborn grafiklerinin genel stilini (tema) ayarlar
#hepsini daha estetik ve okunabilir hale getirir

# %%
# 1. veri setini yükle
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0             0             0           0  SIP101125    MUS1391
# 1             1             1           1  SIP100837    MUS1347
# 2             2             2           2  SIP100050    MUS1066
# 3             3             3           3  SIP100263    MUS1008
# 4             4             4           4  SIP100707    MUS1291
#
#         siparis_tarihi      sehir              bolge    kategori  \
# 0  2024-01-13 17:06:00   İstanbul            Marmara    Kozmetik
# 1  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu        Spor
# 2  2025-06-03 12:42:00    Kayseri         İç Anadolu       Kitap
# 3  2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 4  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
#
#                urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0          Nemlendirici     1       414.51           0.05          49.9
# 1           Dambıl Seti     2      1475.15           0.10          29.9
# 2  İş Analitiği Rehberi     1       289.02           0.05          29.9
# 3          Girişimcilik     5       194.78           0.00          49.9
# 4             Powerbank     3       841.80           0.05          39.9
#
#        odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0     Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1     Banka Kartı          VIP            4.0            1.0       Hayır
# 2     Kredi Kartı       Mevcut            6.0            2.0       Hayır
# 3    Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 4  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
#
#    kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68          2024            1            13
# 1            0.361       2685.17          2025            3            17
# 2            0.348        304.47          2025            6             3
# 3            0.250       1023.80          2024            8            10
# 4            0.280       2439.03          2024            8            19
#
#   haftanin_gunu
# 0      Saturday
# 1        Monday
# 2       Tuesday
# 3      Saturday
# 4        Monday

# %%
# 2. line plot ile zaman içindeki değişimi görselleştirelim
# siparis tarihini date time a çevirelim
df["siparis_tarihi"] = pd.to_datetime(df["siparis_tarihi"])
df["siparis_ayi"] = df["siparis_tarihi"].dt.month
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0             0             0           0  SIP101125    MUS1391
# 1             1             1           1  SIP100837    MUS1347
# 2             2             2           2  SIP100050    MUS1066
# 3             3             3           3  SIP100263    MUS1008
# 4             4             4           4  SIP100707    MUS1291
#
#        siparis_tarihi      sehir              bolge    kategori  \
# 0 2024-01-13 17:06:00   İstanbul            Marmara    Kozmetik
# 1 2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu        Spor
# 2 2025-06-03 12:42:00    Kayseri         İç Anadolu       Kitap
# 3 2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 4 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
#
#                urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0          Nemlendirici     1       414.51           0.05          49.9
# 1           Dambıl Seti     2      1475.15           0.10          29.9
# 2  İş Analitiği Rehberi     1       289.02           0.05          29.9
# 3          Girişimcilik     5       194.78           0.00          49.9
# 4             Powerbank     3       841.80           0.05          39.9
#
#        odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0     Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1     Banka Kartı          VIP            4.0            1.0       Hayır
# 2     Kredi Kartı       Mevcut            6.0            2.0       Hayır
# 3    Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 4  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
#
#    kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68          2024            1            13
# 1            0.361       2685.17          2025            3            17
# 2            0.348        304.47          2025            6             3
# 3            0.250       1023.80          2024            8            10
# 4            0.280       2439.03          2024            8            19
#
#   haftanin_gunu
# 0      Saturday
# 1        Monday
# 2       Tuesday
# 3      Saturday
# 4        Monday

# %%
aylik_toplam_tutar = df.groupby("siparis_ayi")["toplam_tutar"].sum().reset_index()
aylik_toplam_tutar
#indexi alır normal sütuna çevirir
# Out:
#     siparis_ayi  toplam_tutar
# 0             1      81122.86
# 1             2      74048.90
# 2             3      78418.68
# 3             4      76862.50
# 4             5      93420.36
# 5             6      85628.94
# 6             7      73457.11
# 7             8      64133.34
# 8             9      85483.79
# 9            10      71982.43
# 10           11      74683.71
# 11           12      79737.95

# %%
plt.figure(figsize = (6,3))
plt.plot(aylik_toplam_tutar["siparis_ayi"], aylik_toplam_tutar["toplam_tutar"], marker = "o") # line plot
plt.title("Aylara göre toplam tutar")
plt.xlabel("Aylar")
plt.ylabel("Toplam Tutar")
plt.xticks(aylik_toplam_tutar["siparis_ayi"])
plt.tight_layout()
plt.show()

# %%
# 3. scatter plot ile iki sayısal değişken arasındaki ilişkiyi görselleştirelim
plt.figure(figsize = (6,4))
plt.scatter(df["birim_fiyat"], df["toplam_tutar"], alpha = 0.6, color = "red", s = 5)
plt.title("Birim fiyat ve toplam tutar ilişkisi")
plt.xlabel("Birim Fiyat")
plt.ylabel("Toplam Fiyat")
plt.show()

# %%
# 4. bar plot ile karşılaştırmalı görselleştirme
# kategoriye göre toplam tutarı toplayıp bar plot ile görselleştirme
kategori_toplam_tutar = (
    df.groupby("kategori")["toplam_tutar"]
    .sum()
    .sort_values(ascending = False)
    .reset_index()
)
kategori_toplam_tutar
# Out:
#      kategori  toplam_tutar
# 0  Elektronik     243084.26
# 1        Spor     214372.56
# 2    Kozmetik     160225.69
# 3    Ev Yaşam     151605.73
# 4       Kitap     118439.83
# 5        Ofis      51252.50

# %%
plt.figure(figsize = (8,4))
sns.barplot(data = kategori_toplam_tutar, x = "kategori", y = "toplam_tutar")
plt.title("Kategoriye göre toplam tutar")
plt.xlabel("kategori")
plt.ylabel("toplam tutar")
plt.xticks(rotation = 45)
plt.show()

# %%
# 5. histogram ile sayısal dağılım görselleştirme
plt.figure(figsize = (6,5))
plt.hist(df["toplam_tutar"], bins = 150)
plt.title("Toplam tutar dağılımı")
plt.xlabel("toplam tutar")
plt.ylabel("frekans")
plt.show()

# %%
# 6. box plot ile dağılım ve outlier tespiti
plt.figure(figsize = (10,5))
sns.boxplot(data = df, x = "kategori", y = "toplam_tutar")
plt.xlabel("kategori")
plt.ylabel("toplam tutar")
plt.title("Kategoriye göre toplam tutar dağılımı")
plt.show()

# %% [markdown]
# # **Zaman Serisi Analizi**
#
# Amaç:
#
# 1.   Veri setindeki tarih bilgisini kullanarak zaman bazlı analiz yapmak
#
# Adımlar:
#
# 1.   Veri setini yüklemek
# 2.   Sipariş tarihini datetime tipine dönüştür
# 3.   Tarih sütunundan zaman özellikleri türet
# 4.   Aylara göre sipariş yoğunluğunu incele
# 5.   Ayın ilk yarısı ve ikinci yarısında ki harcama farkını incele
# 6.   Hafta içi ve hafta sonu sipariş davranışlarını karşılaştırma
# 7.   İki haftalık dönemlerde ortalama sipariş tutarı inceleme

# %%
# 1. veri setinin yüklenmesi
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0             0             0           0  SIP101125    MUS1391
# 1             1             1           1  SIP100837    MUS1347
# 2             2             2           2  SIP100050    MUS1066
# 3             3             3           3  SIP100263    MUS1008
# 4             4             4           4  SIP100707    MUS1291
#
#         siparis_tarihi      sehir              bolge    kategori  \
# 0  2024-01-13 17:06:00   İstanbul            Marmara    Kozmetik
# 1  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu        Spor
# 2  2025-06-03 12:42:00    Kayseri         İç Anadolu       Kitap
# 3  2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 4  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
#
#                urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0          Nemlendirici     1       414.51           0.05          49.9
# 1           Dambıl Seti     2      1475.15           0.10          29.9
# 2  İş Analitiği Rehberi     1       289.02           0.05          29.9
# 3          Girişimcilik     5       194.78           0.00          49.9
# 4             Powerbank     3       841.80           0.05          39.9
#
#        odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0     Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1     Banka Kartı          VIP            4.0            1.0       Hayır
# 2     Kredi Kartı       Mevcut            6.0            2.0       Hayır
# 3    Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 4  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
#
#    kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68          2024            1            13
# 1            0.361       2685.17          2025            3            17
# 2            0.348        304.47          2025            6             3
# 3            0.250       1023.80          2024            8            10
# 4            0.280       2439.03          2024            8            19
#
#   haftanin_gunu
# 0      Saturday
# 1        Monday
# 2       Tuesday
# 3      Saturday
# 4        Monday

# %%
# 2. sipariş tarihini datetime tipine dönüştür
df["siparis_tarihi"] = pd.to_datetime(df["siparis_tarihi"])
df["siparis_tarihi"].dtype
# Out:
# dtype('<M8[ns]')

# %%
# 3. tarih sütunundan zaman özellikleri üretelim
df["siparis_yili"] = df["siparis_tarihi"].dt.year
df["siparis_ayi"] = df["siparis_tarihi"].dt.month
df["siparis_gunu"] = df["siparis_tarihi"].dt.day
df["haftanin_gunu"] = df["siparis_tarihi"].dt.day_name()
df["hafta_numarasi"] = df["siparis_tarihi"].dt.isocalendar().week.astype(int)
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0             0             0           0  SIP101125    MUS1391
# 1             1             1           1  SIP100837    MUS1347
# 2             2             2           2  SIP100050    MUS1066
# 3             3             3           3  SIP100263    MUS1008
# 4             4             4           4  SIP100707    MUS1291
#
#        siparis_tarihi      sehir              bolge    kategori  \
# 0 2024-01-13 17:06:00   İstanbul            Marmara    Kozmetik
# 1 2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu        Spor
# 2 2025-06-03 12:42:00    Kayseri         İç Anadolu       Kitap
# 3 2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 4 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
#
#                urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0          Nemlendirici     1       414.51           0.05          49.9
# 1           Dambıl Seti     2      1475.15           0.10          29.9
# 2  İş Analitiği Rehberi     1       289.02           0.05          29.9
# 3          Girişimcilik     5       194.78           0.00          49.9
# 4             Powerbank     3       841.80           0.05          39.9
#
#        odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0     Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1     Banka Kartı          VIP            4.0            1.0       Hayır
# 2     Kredi Kartı       Mevcut            6.0            2.0       Hayır
# 3    Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 4  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
#
#    kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68          2024            1            13
# 1            0.361       2685.17          2025            3            17
# 2            0.348        304.47          2025            6             3
# 3            0.250       1023.80          2024            8            10
# 4            0.280       2439.03          2024            8            19
#
#   haftanin_gunu  hafta_numarasi
# 0      Saturday               2
# 1        Monday              12
# 2       Tuesday              23
# 3      Saturday              32
# 4        Monday              34

# %%
# 4. aylara göre sipariş yoğunluk
aylik_yogunluk = (
    df.groupby("siparis_ayi")
    .agg(
        siparis_sayisi = ("siparis_id", "count"),
        benzersiz_musteri_sayisi = ("musteri_id", "nunique")
    )
    .reset_index()
    .sort_values("siparis_ayi")
)
aylik_yogunluk
# Out:
#     siparis_ayi  siparis_sayisi  benzersiz_musteri_sayisi
# 0             1             104                        94
# 1             2              91                        81
# 2             3              99                        83
# 3             4             121                       103
# 4             5             107                        95
# 5             6              91                        77
# 6             7              87                        75
# 7             8              87                        78
# 8             9             102                        89
# 9            10              97                        87
# 10           11             100                        88
# 11           12             100                        90

# %%
plt.figure(figsize = (8,3))
plt.plot(aylik_yogunluk["siparis_ayi"], aylik_yogunluk["siparis_sayisi"], marker = "o", color = "red", label = "siparis_sayisi")
plt.plot(aylik_yogunluk["siparis_ayi"], aylik_yogunluk["benzersiz_musteri_sayisi"], marker = "o", color = "green", label = "benzersiz_musteri_sayisi")
plt.title("Aylara göre sipariş yoğunluğu ve benzersiz müşteri sayısı")
plt.ylabel("Sipariş sayısı ve Benzersiz Müşteri Sayısı")
plt.xlabel("Aylar")
plt.xticks(aylik_yogunluk["siparis_ayi"])
plt.legend()
plt.show()

# %%
# 5. ayın ilk yarısı ve ikinci yarısında ki harcama farkını inceleme
# ayın ilk yarısı ve ikinci yarısı bulma
df["ay_donemi"] = df["siparis_gunu"].apply(
    lambda x: "Ayın ilk yarısı" if x <= 15 else "Ayın ikinci yarısı"
)
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0             0             0           0  SIP101125    MUS1391
# 1             1             1           1  SIP100837    MUS1347
# 2             2             2           2  SIP100050    MUS1066
# 3             3             3           3  SIP100263    MUS1008
# 4             4             4           4  SIP100707    MUS1291
#
#        siparis_tarihi      sehir              bolge    kategori  \
# 0 2024-01-13 17:06:00   İstanbul            Marmara    Kozmetik
# 1 2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu        Spor
# 2 2025-06-03 12:42:00    Kayseri         İç Anadolu       Kitap
# 3 2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 4 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
#
#                urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0          Nemlendirici     1       414.51           0.05          49.9
# 1           Dambıl Seti     2      1475.15           0.10          29.9
# 2  İş Analitiği Rehberi     1       289.02           0.05          29.9
# 3          Girişimcilik     5       194.78           0.00          49.9
# 4             Powerbank     3       841.80           0.05          39.9
#
#        odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0     Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1     Banka Kartı          VIP            4.0            1.0       Hayır
# 2     Kredi Kartı       Mevcut            6.0            2.0       Hayır
# 3    Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 4  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
#
#    kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68          2024            1            13
# 1            0.361       2685.17          2025            3            17
# 2            0.348        304.47          2025            6             3
# 3            0.250       1023.80          2024            8            10
# 4            0.280       2439.03          2024            8            19
#
#   haftanin_gunu  hafta_numarasi           ay_donemi
# 0      Saturday               2     Ayın ilk yarısı
# 1        Monday              12  Ayın ikinci yarısı
# 2       Tuesday              23     Ayın ilk yarısı
# 3      Saturday              32     Ayın ilk yarısı
# 4        Monday              34  Ayın ikinci yarısı

# %%
ay_donemi_analizi = (
    df.groupby("ay_donemi")
    .agg(
        toplam_tutar = ("toplam_tutar", "sum")
    )
    .round(1)
    .reset_index()
)
ay_donemi_analizi
# Out:
#             ay_donemi  toplam_tutar
# 0  Ayın ikinci yarısı      457101.3
# 1     Ayın ilk yarısı      481879.3

# %%
plt.figure()
sns.barplot(data = ay_donemi_analizi, x = "ay_donemi", y= "toplam_tutar")
plt.title("Ayın ilk yarısı ve ikinci yarısına göre toplam tutar")
plt.xlabel("Ay dönemi")
plt.ylabel("Toplam tutar")
plt.show()

# %%
# 6. hafta içi ve hafta sonu sipariş davranışını karşılaştırma
df["hafta_tipi"] = df["siparis_tarihi"].dt.dayofweek.apply(
    lambda x: "hafta sonu" if x >=5 else "hafta içi"
)
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0             0             0           0  SIP101125    MUS1391
# 1             1             1           1  SIP100837    MUS1347
# 2             2             2           2  SIP100050    MUS1066
# 3             3             3           3  SIP100263    MUS1008
# 4             4             4           4  SIP100707    MUS1291
#
#        siparis_tarihi      sehir              bolge    kategori  \
# 0 2024-01-13 17:06:00   İstanbul            Marmara    Kozmetik
# 1 2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu        Spor
# 2 2025-06-03 12:42:00    Kayseri         İç Anadolu       Kitap
# 3 2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 4 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
#
#                urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0          Nemlendirici     1       414.51           0.05          49.9
# 1           Dambıl Seti     2      1475.15           0.10          29.9
# 2  İş Analitiği Rehberi     1       289.02           0.05          29.9
# 3          Girişimcilik     5       194.78           0.00          49.9
# 4             Powerbank     3       841.80           0.05          39.9
#
#        odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0     Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1     Banka Kartı          VIP            4.0            1.0       Hayır
# 2     Kredi Kartı       Mevcut            6.0            2.0       Hayır
# 3    Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 4  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
#
#    kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68          2024            1            13
# 1            0.361       2685.17          2025            3            17
# 2            0.348        304.47          2025            6             3
# 3            0.250       1023.80          2024            8            10
# 4            0.280       2439.03          2024            8            19
#
#   haftanin_gunu  hafta_numarasi           ay_donemi  hafta_tipi
# 0      Saturday               2     Ayın ilk yarısı  hafta sonu
# 1        Monday              12  Ayın ikinci yarısı   hafta içi
# 2       Tuesday              23     Ayın ilk yarısı   hafta içi
# 3      Saturday              32     Ayın ilk yarısı  hafta sonu
# 4        Monday              34  Ayın ikinci yarısı   hafta içi

# %%
hafta_tipi_analizi = (
    df.groupby("hafta_tipi")
    .agg(
        ortalama_siparis_tutari = ("toplam_tutar", "mean"),
    )
    .round(1)
    .reset_index()
)
hafta_tipi_analizi
# Out:
#    hafta_tipi  ortalama_siparis_tutari
# 0   hafta içi                    796.6
# 1  hafta sonu                    780.0

# %%
plt.figure()
sns.barplot(data = hafta_tipi_analizi, x = "hafta_tipi", y = "ortalama_siparis_tutari")
plt.title("Hafta içi ve hafta sonu ortalama sipariş tutarı")
plt.xlabel("Hafta tipi")
plt.ylabel("Ortalama sipariş tutarı")
plt.show()

# %%
# 7. iki haftalık dönemelerde ortalama sipariş tutarı
df["iki_haftalik_donem"] = ((df["hafta_numarasi"] - 1)//2) + 1
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0             0             0           0  SIP101125    MUS1391
# 1             1             1           1  SIP100837    MUS1347
# 2             2             2           2  SIP100050    MUS1066
# 3             3             3           3  SIP100263    MUS1008
# 4             4             4           4  SIP100707    MUS1291
#
#        siparis_tarihi      sehir              bolge    kategori  \
# 0 2024-01-13 17:06:00   İstanbul            Marmara    Kozmetik
# 1 2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu        Spor
# 2 2025-06-03 12:42:00    Kayseri         İç Anadolu       Kitap
# 3 2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 4 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
#
#                urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0          Nemlendirici     1       414.51           0.05          49.9
# 1           Dambıl Seti     2      1475.15           0.10          29.9
# 2  İş Analitiği Rehberi     1       289.02           0.05          29.9
# 3          Girişimcilik     5       194.78           0.00          49.9
# 4             Powerbank     3       841.80           0.05          39.9
#
#        odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0     Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1     Banka Kartı          VIP            4.0            1.0       Hayır
# 2     Kredi Kartı       Mevcut            6.0            2.0       Hayır
# 3    Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 4  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
#
#    kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68          2024            1            13
# 1            0.361       2685.17          2025            3            17
# 2            0.348        304.47          2025            6             3
# 3            0.250       1023.80          2024            8            10
# 4            0.280       2439.03          2024            8            19
#
#   haftanin_gunu  hafta_numarasi           ay_donemi  hafta_tipi  \
# 0      Saturday               2     Ayın ilk yarısı  hafta sonu
# 1        Monday              12  Ayın ikinci yarısı   hafta içi
# 2       Tuesday              23     Ayın ilk yarısı   hafta içi
# 3      Saturday              32     Ayın ilk yarısı  hafta sonu
# 4        Monday              34  Ayın ikinci yarısı   hafta içi
#
#    iki_haftalik_donem
# 0                   1
# 1                   6
# 2                  12
# 3                  16
# 4                  17

# %%
iki_haftalik_analiz = (
    df.groupby("iki_haftalik_donem")
    .agg(
        ortalama_siparis_tutari = ("toplam_tutar", "mean")
    )
    .round(2)
    .reset_index()
    .sort_values("iki_haftalik_donem")
)
iki_haftalik_analiz
# Out:
#     iki_haftalik_donem  ortalama_siparis_tutari
# 0                    1                   754.82
# 1                    2                   820.04
# 2                    3                   910.34
# 3                    4                   819.45
# 4                    5                   656.75
# 5                    6                   821.12
# 6                    7                   842.69
# 7                    8                   597.74
# 8                    9                   626.87
# 9                   10                   872.81
# 10                  11                   865.59
# 11                  12                   926.87
# 12                  13                   961.01
# 13                  14                   907.66
# 14                  15                   791.53
# 15                  16                   773.66
# 16                  17                   728.22
# 17                  18                   801.63
# 18                  19                   855.21
# 19                  20                   770.26
# 20                  21                   782.41
# 21                  22                   743.73
# 22                  23                   604.38
# 23                  24                   859.96
# 24                  25                   856.10
# 25                  26                   629.36

# %%
plt.figure(figsize = (10,4))
plt.plot(iki_haftalik_analiz["iki_haftalik_donem"], iki_haftalik_analiz["ortalama_siparis_tutari"], marker = "o")
plt.title("İki haftalık dönemlere göre ortalama sipariş tutarı")
plt.xlabel("iki haftalık dönem")
plt.xticks(iki_haftalik_analiz["iki_haftalik_donem"])
plt.ylabel("ortalama sipariş tutarı")
plt.show()

# %% [markdown]
# # **Değişkenler Arası İlişkiler**
#
# Amaç:
#
# 1.   Sayısal değişkenler arasındaki ilişkileri korelasyon analizi ile incelemek
# 2.   Heatmap ile görselleştirme yapmak
#
# Adımlar:
#
# 1.   Veri setini yüklemek
# 2.   Sayısal sütunları belirle
# 3.   Korelasyon matrisi oluştur
# 4.   Korelasyon matrisi heatmap ile görselleştir

# %%
# 1. veri setini yükleme
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0             0             0           0  SIP101125    MUS1391
# 1             1             1           1  SIP100837    MUS1347
# 2             2             2           2  SIP100050    MUS1066
# 3             3             3           3  SIP100263    MUS1008
# 4             4             4           4  SIP100707    MUS1291
#
#         siparis_tarihi      sehir              bolge    kategori  \
# 0  2024-01-13 17:06:00   İstanbul            Marmara    Kozmetik
# 1  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu        Spor
# 2  2025-06-03 12:42:00    Kayseri         İç Anadolu       Kitap
# 3  2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 4  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
#
#                urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0          Nemlendirici     1       414.51           0.05          49.9
# 1           Dambıl Seti     2      1475.15           0.10          29.9
# 2  İş Analitiği Rehberi     1       289.02           0.05          29.9
# 3          Girişimcilik     5       194.78           0.00          49.9
# 4             Powerbank     3       841.80           0.05          39.9
#
#        odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0     Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1     Banka Kartı          VIP            4.0            1.0       Hayır
# 2     Kredi Kartı       Mevcut            6.0            2.0       Hayır
# 3    Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 4  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
#
#    kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68          2024            1            13
# 1            0.361       2685.17          2025            3            17
# 2            0.348        304.47          2025            6             3
# 3            0.250       1023.80          2024            8            10
# 4            0.280       2439.03          2024            8            19
#
#   haftanin_gunu
# 0      Saturday
# 1        Monday
# 2       Tuesday
# 3      Saturday
# 4        Monday

# %%
# 2. sayısal sütunları belirle
sayisal_sutunlar = df.select_dtypes(include = ["int64", "float64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['Unnamed: 0.2',
#  'Unnamed: 0.1',
#  'Unnamed: 0',
#  'adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar',
#  'siparis_yili',
#  'siparis_ayi',
#  'siparis_gunu']

# %%
# 3. korelasyon matrisi
korelasyon_matrisi = df[sayisal_sutunlar].corr()
korelasyon_matrisi
# Out:
#                  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0      adet  \
# Unnamed: 0.2         1.000000      0.999991    0.999991  0.046382
# Unnamed: 0.1         0.999991      1.000000    1.000000  0.046198
# Unnamed: 0           0.999991      1.000000    1.000000  0.046198
# adet                 0.046382      0.046198    0.046198  1.000000
# birim_fiyat          0.013280      0.013492    0.013492 -0.172545
# indirim_orani        0.001496      0.001517    0.001517 -0.002466
# kargo_ucreti         0.003617      0.003786    0.003786  0.032133
# teslimat_gunu       -0.035797     -0.035838   -0.035838 -0.013187
# musteri_puani       -0.035525     -0.035551   -0.035551 -0.001518
# kar_marji_orani      0.013450      0.013289    0.013289  0.008099
# toplam_tutar         0.034682      0.034791    0.034791  0.425261
# siparis_yili         0.027418      0.027582    0.027582  0.014705
# siparis_ayi         -0.034652     -0.034903   -0.034903  0.084759
# siparis_gunu        -0.009720     -0.009871   -0.009871 -0.001103
#
#                  birim_fiyat  indirim_orani  kargo_ucreti  teslimat_gunu  \
# Unnamed: 0.2        0.013280       0.001496      0.003617      -0.035797
# Unnamed: 0.1        0.013492       0.001517      0.003786      -0.035838
# Unnamed: 0          0.013492       0.001517      0.003786      -0.035838
# adet               -0.172545      -0.002466      0.032133      -0.013187
# birim_fiyat         1.000000      -0.001571      0.009513      -0.021566
# indirim_orani      -0.001571       1.000000      0.009259       0.060925
# kargo_ucreti        0.009513       0.009259      1.000000       0.000667
# teslimat_gunu      -0.021566       0.060925      0.000667       1.000000
# musteri_puani      -0.001885      -0.003986      0.001636      -0.000634
# kar_marji_orani    -0.029501      -0.005531      0.007755       0.034022
# toplam_tutar        0.718637      -0.048178      0.037641      -0.018820
# siparis_yili       -0.006057       0.030659      0.084407       0.041525
# siparis_ayi        -0.048085       0.029693     -0.036316       0.007759
# siparis_gunu       -0.016287       0.002346      0.007812      -0.001573
#
#                  musteri_puani  kar_marji_orani  toplam_tutar  siparis_yili  \
# Unnamed: 0.2         -0.035525         0.013450      0.034682      0.027418
# Unnamed: 0.1         -0.035551         0.013289      0.034791      0.027582
# Unnamed: 0           -0.035551         0.013289      0.034791      0.027582
# adet                 -0.001518         0.008099      0.425261      0.014705
# birim_fiyat          -0.001885        -0.029501      0.718637     -0.006057
# indirim_orani        -0.003986        -0.005531     -0.048178      0.030659
# kargo_ucreti          0.001636         0.007755      0.037641      0.084407
# teslimat_gunu        -0.000634         0.034022     -0.018820      0.041525
# musteri_puani         1.000000         0.014662      0.013423     -0.038700
# kar_marji_orani       0.014662         1.000000     -0.015829     -0.023314
# toplam_tutar          0.013423        -0.015829      1.000000      0.004806
# siparis_yili         -0.038700        -0.023314      0.004806      1.000000
# siparis_ayi          -0.035946         0.015447     -0.000713      0.048424
# siparis_gunu         -0.020190        -0.019906     -0.024604     -0.043268
#
#                  siparis_ayi  siparis_gunu
# Unnamed: 0.2       -0.034652     -0.009720
# Unnamed: 0.1       -0.034903     -0.009871
# Unnamed: 0         -0.034903     -0.009871
# adet                0.084759     -0.001103
# birim_fiyat        -0.048085     -0.016287
# indirim_orani       0.029693      0.002346
# kargo_ucreti       -0.036316      0.007812
# teslimat_gunu       0.007759     -0.001573
# musteri_puani      -0.035946     -0.020190
# kar_marji_orani     0.015447     -0.019906
# toplam_tutar       -0.000713     -0.024604
# siparis_yili        0.048424     -0.043268
# siparis_ayi         1.000000     -0.033585
# siparis_gunu       -0.033585      1.000000

# %%
# 4. korelasyon matrisini heatmap ile görselleştirme
sns.heatmap(korelasyon_matrisi, annot = True, fmt = ".1f", cmap = "coolwarm", linewidth = 0.5)
plt.title("Korelasyon Analizi")
plt.show()

# %% [markdown]
# # **Veri Hikayeleştirme ve İş Yorumu**
#
# Amaç:
#
# 1.   Gerçek hayata benzeyen iş sorularını veri ile cevaplamak
# 2.   Analiz sonuçlarını tablo, grafik ve kısa iş yorumları ile sunmak
#
# Adımlar:
#
# 1.   Hangi kategori hem yüksek gelir üretiyor hem de müşteri memnuniyeti açısından güçlü görünüyor?
# 2.   Hangi ödeme türleri daha yüksek ortalama sipariş tutarı üretiyor ve müşteri puanı açısından performans gösteriyor?
# 3.   Hangi şehir-kategori kombinasyonları en güçlü fırsatı sunuyor?

# %%
df = pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 siparis_id musteri_id  \
# 0             0             0           0  SIP101125    MUS1391
# 1             1             1           1  SIP100837    MUS1347
# 2             2             2           2  SIP100050    MUS1066
# 3             3             3           3  SIP100263    MUS1008
# 4             4             4           4  SIP100707    MUS1291
#
#         siparis_tarihi      sehir              bolge    kategori  \
# 0  2024-01-13 17:06:00   İstanbul            Marmara    Kozmetik
# 1  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu        Spor
# 2  2025-06-03 12:42:00    Kayseri         İç Anadolu       Kitap
# 3  2024-08-10 15:13:00    Antalya            Akdeniz       Kitap
# 4  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu  Elektronik
#
#                urun_adi  adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# 0          Nemlendirici     1       414.51           0.05          49.9
# 1           Dambıl Seti     2      1475.15           0.10          29.9
# 2  İş Analitiği Rehberi     1       289.02           0.05          29.9
# 3          Girişimcilik     5       194.78           0.00          49.9
# 4             Powerbank     3       841.80           0.05          39.9
#
#        odeme_turu musteri_tipi  teslimat_gunu  musteri_puani iade_durumu  \
# 0     Kredi Kartı         Yeni            3.0            5.0       Hayır
# 1     Banka Kartı          VIP            4.0            1.0       Hayır
# 2     Kredi Kartı       Mevcut            6.0            2.0       Hayır
# 3    Kapıda Ödeme         Yeni            3.0            5.0       Hayır
# 4  Dijital Cüzdan       Mevcut            4.0            5.0       Hayır
#
#    kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  \
# 0            0.220        443.68          2024            1            13
# 1            0.361       2685.17          2025            3            17
# 2            0.348        304.47          2025            6             3
# 3            0.250       1023.80          2024            8            10
# 4            0.280       2439.03          2024            8            19
#
#   haftanin_gunu
# 0      Saturday
# 1        Monday
# 2       Tuesday
# 3      Saturday
# 4        Monday

# %%
# 1. hangi kategori hem yüksek gelir hem de müşteri memnuniyetini yüksek sağlıyor
kategori_raporu = (
    df.groupby("kategori")
    .agg(
        toplam_gelir = ("toplam_tutar", "sum"),
        ortalama_musteri_puani = ("musteri_puani", "mean")
    )
    .round(2)
)

# %%
kategori_raporu = kategori_raporu.sort_values(by = ["toplam_gelir"], ascending=[False])
kategori_raporu
# Out:
#             toplam_gelir  ortalama_musteri_puani
# kategori
# Elektronik     243084.26                    3.97
# Spor           214372.56                    3.96
# Kozmetik       160225.69                    4.13
# Ev Yaşam       151605.73                    3.87
# Kitap          118439.83                    3.99
# Ofis            51252.50                    3.94

# %%
# kategoriye göre toplam gelir
plt.figure(figsize = (8,4))
sns.barplot(data = kategori_raporu, x = "kategori", y = "toplam_gelir")
plt.title("Kategoriye göre toplam gelir")
plt.xlabel("Kategori")
plt.ylabel("Toplam Gelir")
plt.show()

# %%
# kategoriye göre ortalama musteri puani
plt.figure(figsize = (8,4))
sns.barplot(data = kategori_raporu, x = "kategori", y = "ortalama_musteri_puani")
plt.title("Kategoriye göre ortalama müşteri puanı")
plt.xlabel("Kategori")
plt.ylabel("Müşteri Puanı")
plt.show()

# %%
# 2. hangi ödeme türleri daha yüksek ortalama sipariş tutarı üretiyor ve müşteri puanı açısından nasıl performans gösteriyor?
odeme_turu_raporu = (
    df.groupby("odeme_turu")
    .agg(
        ortalama_siparis_tutari = ("toplam_tutar", "mean"),
        ortalama_musteri_puani = ("musteri_puani", "mean")
    )
    .round(2)
    .sort_values("ortalama_siparis_tutari", ascending = False)
)
odeme_turu_raporu
# Out:
#                 ortalama_siparis_tutari  ortalama_musteri_puani
# odeme_turu
# Dijital Cüzdan                   894.83                    3.99
# Banka Kartı                      853.38                    3.85
# Havale/EFT                       834.39                    3.85
# Kredi Kartı                      744.50                    4.05
# Kapıda Ödeme                     674.87                    4.00

# %%
# ödeme türüne göre ortalama sipariş tutarı
plt.figure(figsize = (8,4))
sns.barplot(data = odeme_turu_raporu, x = "odeme_turu", y = "ortalama_siparis_tutari")
plt.title("Ödeme türüne göre ortalama sipariş tutarı")
plt.xlabel("Ödeme Türü")
plt.ylabel("Ortalama Sipariş Tutarı")
plt.show()

# %%
# ödeme türüne göre ortalama müşteri puanı
plt.figure(figsize = (8,4))
sns.barplot(data = odeme_turu_raporu, x = "odeme_turu", y = "ortalama_musteri_puani")
plt.title("Ödeme türüne göre ortalama müşteri puanı")
plt.xlabel("Ödeme Türü")
plt.ylabel("Ortalama müşteri puanı")
plt.show()

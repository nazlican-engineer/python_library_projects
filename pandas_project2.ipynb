# %%
import pandas as pd
from datasets import load_dataset

#loading data
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
pip install --upgrade huggingface_hub

# %%
# !pip install --upgrade datasets

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.job_posted_date[0]
# Out:
# '2023-06-16 13:44:15'

# %%
dt=pd.to_datetime(df.job_posted_date)

# %%
type(dt)
# Out:
# pandas.core.series.Series

# %%
dt
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# 785740   2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: datetime64[ns]

# %%
df["job_posted_date"]=pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_posted_date.dt.month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
df['job_posted_month']=df.job_posted_date.dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_posted_month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_month, Length: 785741, dtype: int32

# %%
df["job_posted_day"]=df.job_posted_date.dt.day

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.job_posted_day
# Out:
# 0         16
# 1         14
# 2         10
# 3          4
# 4          7
#           ..
# 785736    13
# 785737    12
# 785738    12
# 785739    12
# 785740    13
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
df.sort_values("job_posted_day",inplace=True) #inplace metodu otomotikmen false değerindedir bu metodu true olarak döndürürsek orijinal dataframe üzerinde işlem yapmamızı sağlar
#ve bu değer geri döndürülemez olduğu için orojinal datafram üzerinde daha sonra yapacağım değişiklikler üzerinde datafremimi yedeklemem lazım.

# %%
df
# Out:
#                   job_title_short  \
# 224074               Data Analyst
# 402695  Machine Learning Engineer
# 582669               Data Analyst
# 357237      Senior Data Scientist
# 629166       Senior Data Engineer
# ...                           ...
# 194838             Data Scientist
# 194849        Senior Data Analyst
# 194890              Data Engineer
# 194414              Data Engineer
# 194553        Senior Data Analyst
#
#                                                 job_title  \
# 224074                                       Data Analyst
# 402695                Senior PowerBI Engineer - R01522880
# 582669                                 Data Administrator
# 357237  Senior Data Scientist, International Growth at...
# 629166                  Senior Data Engineer Fully-remote
# ...                                                   ...
# 194838                                Lead Data Scientist
# 194849                                Senior Data Analyst
# ...

# %%
df.drop(labels="salary_hour_avg",axis=1) #drop metodu istediğim bi kısmı silmek için kullanılır axis 1 ise salary hour avg nin sütununu siler 0 ise satırını siler.
#kalıcı  yapmak istersem inplace metodunu kullanırım.
# Out:
#                   job_title_short  \
# 224074               Data Analyst
# 402695  Machine Learning Engineer
# 582669               Data Analyst
# 357237      Senior Data Scientist
# 629166       Senior Data Engineer
# ...                           ...
# 194838             Data Scientist
# 194849        Senior Data Analyst
# 194890              Data Engineer
# 194414              Data Engineer
# 194553        Senior Data Analyst
#
#                                                 job_title  \
# 224074                                       Data Analyst
# 402695                Senior PowerBI Engineer - R01522880
# 582669                                 Data Administrator
# 357237  Senior Data Scientist, International Growth at...
# 629166                  Senior Data Engineer Fully-remote
# ...                                                   ...
# 194838                                Lead Data Scientist
# 194849                                Senior Data Analyst
# ...

# %%
df.drop(labels="salary_year_avg",axis=1,inplace=True)

# %%
df
# Out:
#                   job_title_short  \
# 224074               Data Analyst
# 402695  Machine Learning Engineer
# 582669               Data Analyst
# 357237      Senior Data Scientist
# 629166       Senior Data Engineer
# ...                           ...
# 194838             Data Scientist
# 194849        Senior Data Analyst
# 194890              Data Engineer
# 194414              Data Engineer
# 194553        Senior Data Analyst
#
#                                                 job_title  \
# 224074                                       Data Analyst
# 402695                Senior PowerBI Engineer - R01522880
# 582669                                 Data Administrator
# 357237  Senior Data Scientist, International Growth at...
# 629166                  Senior Data Engineer Fully-remote
# ...                                                   ...
# 194838                                Lead Data Scientist
# 194849                                Senior Data Analyst
# ...

# %%
df.dropna(subset=["salary_hour_avg"]) #salary_hour_avg deki sütunlara bakar ve değerleri NaN olanları siler.
# Out:
#               job_title_short  \
# 357237  Senior Data Scientist
# 356968           Data Analyst
# 109837           Data Analyst
# 629402           Data Analyst
# 785492         Data Scientist
# ...                       ...
# 203127           Data Analyst
# 201472           Data Analyst
# 190942           Data Analyst
# 546030         Data Scientist
# 196997   Senior Data Engineer
#
#                                                 job_title       job_location  \
# 357237  Senior Data Scientist, International Growth at...          Plano, TX
# 356968    Data Analyst at Emory University in Atlanta, GA        Atlanta, GA
# 109837  Data Analyst, Partner Operations (Ecosystem Pa...  San Francisco, CA
# 629402                                   SAP Data Analyst        Atlanta, GA
# 785492                                     Data Scientist      Arlington, VA
# ...                                                   ...                ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 224074 to 194553
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_hour_avg        10662 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
df.dropna(subset=["salary_hour_avg"],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10662 entries, 357237 to 196997
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        10662 non-null  object
#  1   job_title              10662 non-null  object
#  2   job_location           10586 non-null  object
#  3   job_via                10654 non-null  object
#  4   job_schedule_type      10536 non-null  object
#  5   job_work_from_home     10662 non-null  bool
#  6   search_location        10662 non-null  object
#  7   job_posted_date        10662 non-null  datetime64[ns]
#  8   job_no_degree_mention  10662 non-null  bool
#  9   job_health_insurance   10662 non-null  bool
#  10  job_country            10662 non-null  object
#  11  salary_rate            10662 non-null  object
#  12  salary_hour_avg        10662 non-null  float64
#  13  company_name           10662 non-null  object
# ...

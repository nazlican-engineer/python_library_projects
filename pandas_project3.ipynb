# %%
import pandas as pd
from datasets import load_dataset


dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

# %%
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()

# %%
pip install --upgrade huggingface_hub

# %%
# !pip install --upgrade datasets

# %%
df.describe() #veri setine hızlıca bakmak,gözden geçirmek için kullanılır.
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df.count()#her sütunda toplam kaç tane boş olmayan değer vardır
# Out:
# job_title_short          785741
# job_title                785740
# job_location             784696
# job_via                  785733
# job_schedule_type        773074
# job_work_from_home       785741
# search_location          785741
# job_posted_date          785741
# job_no_degree_mention    785741
# job_health_insurance     785741
# job_country              785692
# salary_rate               33067
# salary_year_avg           22003
# salary_hour_avg           10662
# company_name             785723
# job_skills               668704
# job_type_skills          668704
# dtype: int64

# %%
df.median() #dataframin geneline uyguladığımda hata alırım çünkü  geçerli  olmayan string gibi ifadeler de var
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-61-530051474.py in <cell line: 0>()
# ----> 1 df.median()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11704         **kwargs,
#   11705     ):
# > 11706         result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707         if isinstance(result, Series):
#   11708             result = result.__finalize__(self, method="median")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   12429         **kwargs,
#   12430     ) -> Series | float:
# > 12431         return self._stat_function(
#   12432             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   12433         )
#
# ...

# %%
df["salary_year_avg"].median()
# Out:
# 115000.0

# %%
df["salary_year_avg"].min()#en düşük değerin ne olduğunu gösterir
# Out:
# 15000.0

# %%
min_salary=df.salary_year_avg.idxmin()#minumum değer hangi satırda onu gösterir

# %%
df.iloc[min_salary]#en düşük maaşa sahip olan kişinin  bilgilerini getirir
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# ...

# %%
df.job_title_short.unique()#kaç farklı meslek olduğunu  gösterir
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
#count metodu her bir sütunda kaç tane  none olmayan değerler haricindeki değerleri saymak için kullanılır
#value_counts ise o sütunda her bir değerin kaç defa geçtiğini gösterir
df.job_title_short.value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
#df.groupby("sütun_adı_1")["sütun_adı_2"].agg_fonksiyonu()
#group by methodu açıklama:birinci kısım hangi sütun üzerinden gruplama yapacağımı,ikinci kısım hangi sütunu seçtin üzerinde işlem yapmak içi,3.kısım ise hangi işlemi yapacağını gösterir

df.groupby("job_title_short")["job_title_short"].min()
# Out:
# job_title_short
# Business Analyst                      Business Analyst
# Cloud Engineer                          Cloud Engineer
# Data Analyst                              Data Analyst
# Data Engineer                            Data Engineer
# Data Scientist                          Data Scientist
# Machine Learning Engineer    Machine Learning Engineer
# Senior Data Analyst                Senior Data Analyst
# Senior Data Engineer              Senior Data Engineer
# Senior Data Scientist            Senior Data Scientist
# Software Engineer                    Software Engineer
# Name: job_title_short, dtype: object

# %%
df.groupby("job_title_short")["salary_year_avg"].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby(["job_title_short","job_country"])["salary_year_avg"].min()
# Out:
# job_title_short    job_country
# Business Analyst   Afghanistan        NaN
#                    Albania            NaN
#                    Algeria            NaN
#                    Angola             NaN
#                    Argentina      63000.0
#                                    ...
# Software Engineer  Venezuela          NaN
#                    Vietnam        28000.0
#                    Yemen              NaN
#                    Zambia             NaN
#                    Zimbabwe           NaN
# Name: salary_year_avg, Length: 1387, dtype: float64

# %%
df.groupby("job_title_short")[["salary_year_avg","salary_hour_avg"]].min()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst                   16500.0           10.835
# Cloud Engineer                     42000.0           18.500
# Data Analyst                       25000.0            8.000
# Data Engineer                      15000.0            8.000
# Data Scientist                     27000.0            8.000
# Machine Learning Engineer          30000.0           10.000
# Senior Data Analyst                30000.0           13.000
# Senior Data Engineer               35000.0           12.500
# Senior Data Scientist              45000.0           17.500
# Software Engineer                  28000.0           11.000

# %%
df.groupby("job_title_short")["salary_year_avg"].agg(["min","max","median"])
#birden fazla işlem yaparsak agg  kullanmamız lazım
# Out:
#                                min       max    median
# job_title_short
# Business Analyst           16500.0  387460.0   85000.0
# Cloud Engineer             42000.0  280000.0   90000.0
# Data Analyst               25000.0  650000.0   90000.0
# Data Engineer              15000.0  525000.0  125000.0
# Data Scientist             27000.0  960000.0  127500.0
# Machine Learning Engineer  30000.0  325000.0  106415.0
# Senior Data Analyst        30000.0  425000.0  111175.0
# Senior Data Engineer       35000.0  425000.0  147500.0
# Senior Data Scientist      45000.0  890000.0  155500.0
# Software Engineer          28000.0  375000.0   99150.0
